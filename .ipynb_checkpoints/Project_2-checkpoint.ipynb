# %% [markdown]
# <a href="https://colab.research.google.com/github/DS3001/group22/blob/main/Project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Programming Lab #2
# ## Foundations of Machine Learning
#
# The purpose of this project is to build predictive algorithms that predict the likelihood a person has a stroke. The data include:
#
#   - `age`: Patient age, numeric
#   - `avg_glucose_level`: Blood sugar levels, numeric
#   - `bmi`: Body mass index, numeric
#   - `ever_married`: Ever married, dummy/character (Yes, No)
#   - `gender`: Male, Female, or Other, character
#   - `heart_disease`: Has heart disease, dummy
#   - `hypertension`: Has hypertension, dummy
#   - `id`: Study identification number
#   - `Residence_type`: Type of residence, dummy/character (Urban, Rural)
#   - `smoking_status`: Former, never, or current smoker, categorical
#   - `work_type`: Employment type (Never worked (Never_worked), homemaker ("children"), Public sector employment (Govt_job), Private sector employment (`Private`), Self-employed (`Self-employed`)
#   - `stroke`: Suffered a stroke in the sample period
#
# The data come in two files: `training_data.csv`, which you should use to build your models, and `testing_data.csv`, which you should use to test your models. The models must be trained on the training data and tested on the testing data, but providing both files allows you to experiment with your choices and iterate on model designs. If performance drops on the testing data, you know there's a problem.
#
# You can use any of the tools presented in class: $k$ nearest neighbor, linear models, or decision trees. In principle, $k$ means clustering might also be helpful for looking for patterns in the data that the other methods might miss. Using canned versions of more advanced tools (boosting, bagging, random forests, neural networks, etc.) is deeply unsporting and thus not allowed. You can be creative about transforming variables, or combining decision trees with linear models or $k$NN. Try something interesting. Fail extravagantly. The goal is to work on an intellectually interesting question that is similar to the tasks that data scientists are called on to do every day.
#
# We will compare the groups' models to see if there are common trends or significant differences, and also to declare **The Winners** on the basis of whichever team achieves the lowest $RMSE$ on the testing data. A simple linear model with some polynomials and dummy variables achieves an $R^2$ of .087 and a $RMSE$ of .206.

# %%
import pandas as pd
import numpy as np
df_train = pd.read_csv('https://raw.githubusercontent.com/DS3001/group22/main/project_2/data/training_data.csv')
df_test = pd.read_csv('https://raw.githubusercontent.com/DS3001/group22/main/project_2/data/testing_data.csv')

y_train = df_train['stroke']
X_train = df_train.drop('stroke',axis=1)
y_test = df_test['stroke']
X_test = df_test.drop('stroke',axis=1)

X_train['bmi'] = X_train['bmi'].fillna(X_train['bmi'].mean())
X_test['bmi'] = X_test['bmi'].fillna(X_test['bmi'].mean())

# %%
## Linear Model
from sklearn.linear_model import LinearRegression # Import linear regression model
from sklearn.preprocessing import PolynomialFeatures

X_train_numeric = X_train.loc[:,['age','hypertension','heart_disease','bmi','avg_glucose_level'] ]
#
expander = PolynomialFeatures(degree=2,include_bias=False) # Create the expander
Z = expander.fit_transform(X_train_numeric) # Pass the df into the expander to get powers/interactions of x and y
names = expander.get_feature_names_out() # Get the names of these variables
continuous = pd.DataFrame(data=Z, columns = names) # Create a new, expanded dataframe
#
dummies = pd.concat([ pd.get_dummies(X_train['work_type'],dtype='int',drop_first=True),
                      pd.get_dummies(X_train['Residence_type'],dtype='int',drop_first=True),
                      pd.get_dummies(X_train['smoking_status'],dtype='int',drop_first=True)],axis=1)
#
Z_train = pd.concat([continuous,dummies],axis=1)

X_test_numeric = X_test.loc[:,['age','hypertension','heart_disease','bmi','avg_glucose_level'] ]
#
expander = PolynomialFeatures(degree=2,include_bias=False) # Create the expander
Z = expander.fit_transform(X_test_numeric) # Pass the df into the expander to get powers/interactions of x and y
names = expander.get_feature_names_out() # Get the names of these variables
continuous = pd.DataFrame(data=Z, columns = names) # Create a new, expanded dataframe

dummies = pd.concat([ pd.get_dummies(X_test['work_type'],dtype='int',drop_first=True),
                      pd.get_dummies(X_test['Residence_type'],dtype='int',drop_first=True),
                      pd.get_dummies(X_test['smoking_status'],dtype='int',drop_first=True)],axis=1)
#
Z_test = pd.concat([continuous,dummies],axis=1)

# Fit the model and get the R2 measure:
reg = LinearRegression().fit(Z_train, y_train) # Fit the linear model
print('R2: ', reg.score(Z_test, y_test)) # R squared measure
y_hat = reg.predict(Z_test)
N = len(y_test)
print('RMSE: ', (np.sum( (y_test - y_hat)**2)/N )**.5 )   # R squared measure
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-d0f16b984d5a> in <module>
#       7 expander = PolynomialFeatures(degree=2,include_bias=False) # Create the expander
#       8 Z = expander.fit_transform(X_train_numeric) # Pass the df into the expander to get powers/interactions of x and y
# ----> 9 names = expander.get_feature_names_out() # Get the names of these variables
#      10 continuous = pd.DataFrame(data=Z, columns = names) # Create a new, expanded dataframe
#      11 #
#
# AttributeError: 'PolynomialFeatures' object has no attribute 'get_feature_names_out'

# %% [markdown]
# This is supposed to be fairly "fun," so please do not turn it into a combinatorial nightmare of comparing thousands of model specifications. Settle on a strategy you think is promising, crank it out, and write up the results. Your time and energy are valuable, so learn to recognize when the marginal cost of another twenty minutes on a project exceeds the benefit in terms of improving the results and your grade.
#
# ## Paper format
#
# The format of the paper should be:
#
#   - Summary: A one paragraph description of the question, methods, and results (about 350 words).
#   - Data: One to two pages discussing the data and key variables, and any challenges in reading, cleaning, and preparing them for analysis.
#   - Results: Two to five pages providing visualizations, statistics, a discussion of your methodology, and a presentation of your main findings.
#   - Conclusion: One to two pages summarizing the project, defending it from criticism, and suggesting additional work that was outside the scope of the project.
#   - Appendix: If you have a significant number of additional plots or table that you feel are essential to the project, you can put any amount of extra content at the end and reference it from the body of the paper.
#
# ## Submission
#
# Half of each student's grade is based on their commits to the repo. Each student is expected to do something specific that contributes to the overall project outcome. Since commits are recorded explicitly by Git/GitHub, this is observable. A student can contribute by cleaning data, creating visualizations,performing analytic analyses,  or writing about results, but everyone has to do something substantial. A student's work doesn't need to make it into the final report to be valuable and substantial, and fulfill the requirement to make a contribution to the project.
#
# The other half of each student's grade is based on the written report. Groups will work together on combining results and writing up findings in a Jupyter noteb,ok, using code chunks to execute Python commands and markdown chunks to structure the paper and provide exposition. The notebook should run on Colab or Rivana from beginning to end without any errors.
#
# mbers submit.
#
# ## Criteria
#
# The project is graded based on four criteria:
#
#   - Project Concept: What is the strategy for building and testing the group's models? How did the group decide how to use the tools presented so far in class? How did the group compare the performance of the options considered, and settle on a final choice for submission?
#   - Wrangling, EDA, and Visualization: How are are missing values handled? For variables with large numbers of missing values, to what extent do the data and documentation provide an explanation for the missing data? If multiple data sources are used, how are the data merged? For the main variables in the analysis, are the relevant data summarized and visualized through a histogram or kernel density plot where appropriate? Are basic quantitative features of the data addressed and explained? How are outliers characterized and addressed?
#   - Analysis: What are the groups' main findings? Do the tables, plots, and statistics support the conclusions? Is the research strategy carried out correctly? If the research strategy succeeds, are the results interpreted correctly and appropriately? If the research strategy fails, is a useful discussion of the flaws of the data collection process or the research strategy discussed?
#   - Replication/Documentation: Is the code appropriately commented? Can the main results be replicated from the code and original data files? Are significant choices noted and explained?
#
# Each of the four criteria are equally weighted (25 points out of 100).

# %% [markdown]
# # **Data Wrangling**

# %% [markdown]
# # age

# %%
var = 'age'
df_train[var].unique()
# Out:
# array([3.60e+01, 4.50e+01, 5.80e+01, 6.10e+01, 7.80e+01, 3.40e+01,
#        3.70e+01, 6.30e+01, 7.20e+01, 5.90e+01, 2.60e+01, 4.60e+01,
#        1.70e+01, 2.90e+01, 1.60e+01, 4.40e+01, 7.90e+01, 7.30e+01,
#        3.00e+01, 5.00e+00, 3.20e-01, 1.30e+01, 2.20e+01, 8.00e+01,
#        6.20e+01, 6.70e+01, 5.60e+01, 1.10e+01, 4.00e+01, 2.40e-01,
#        9.00e+00, 6.00e+01, 7.40e+01, 2.80e+01, 5.10e+01, 5.20e+01,
#        3.20e+01, 2.50e+01, 8.20e+01, 3.50e+01, 2.30e+01, 4.70e+01,
#        5.50e+01, 2.70e+01, 6.00e+00, 3.30e+01, 4.90e+01, 5.30e+01,
#        4.20e+01, 5.70e+01, 6.60e+01, 7.10e+01, 1.60e-01, 5.40e+01,
#        3.00e+00, 7.00e+00, 6.40e+01, 4.30e+01, 3.10e+01, 2.10e+01,
#        6.50e+01, 1.80e+01, 4.10e+01, 8.10e+01, 1.00e+00, 2.40e+01,
#        3.90e+01, 7.00e+01, 2.00e+00, 4.80e+01, 8.00e-02, 3.80e+01,
#        7.50e+01, 1.88e+00, 1.00e+01, 1.20e+01, 6.40e-01, 2.00e+01,
#        5.00e+01, 7.70e+01, 1.90e+01, 1.08e+00, 8.00e+00, 6.90e+01,
#        6.80e+01, 1.40e+01, 4.00e+00, 7.60e+01, 1.16e+00, 1.80e+00,
#        1.72e+00, 1.32e+00, 1.50e+01, 4.00e-01, 8.80e-01, 7.20e-01,
#        5.60e-01, 1.24e+00, 1.64e+00, 1.56e+00, 4.80e-01, 1.40e+00,
#        8.00e-01, 1.48e+00])

# %%
df_test[var].unique()
# Out:
# array([58.  ,  8.  , 70.  , 47.  , 74.  , 79.  , 40.  , 35.  , 44.  ,
#        71.  , 23.  , 69.  , 21.  , 78.  , 24.  , 60.  , 66.  , 52.  ,
#        34.  , 57.  , 41.  , 56.  ,  0.88, 25.  , 39.  , 31.  , 61.  ,
#        22.  , 42.  , 33.  , 68.  , 26.  , 43.  , 53.  , 55.  , 64.  ,
#        38.  ,  5.  , 54.  , 72.  , 51.  , 20.  , 65.  , 16.  , 46.  ,
#        67.  , 18.  ,  1.08,  1.8 , 80.  , 37.  ,  9.  , 28.  , 10.  ,
#        82.  ,  2.  , 32.  , 30.  , 45.  , 50.  ,  6.  , 73.  , 27.  ,
#        63.  , 59.  , 29.  , 36.  ,  1.  , 48.  ,  1.4 , 19.  ,  1.72,
#        77.  , 75.  , 15.  , 49.  , 14.  , 81.  ,  1.64, 13.  , 11.  ,
#        62.  , 76.  ,  4.  , 12.  ,  7.  ,  1.48,  0.24,  0.64,  0.48,
#         3.  ,  1.24, 17.  ,  1.16,  0.56,  0.72,  0.16,  1.32,  0.32])

# %%
df_train[var] = df_train[var].round().astype(int)
df_test[var] = df_test[var].round().astype(int)

# %%
df_train[var].unique()
# Out:
# array([36, 45, 58, 61, 78, 34, 37, 63, 72, 59, 26, 46, 17, 29, 16, 44, 79,
#        73, 30,  5,  0, 13, 22, 80, 62, 67, 56, 11, 40,  9, 60, 74, 28, 51,
#        52, 32, 25, 82, 35, 23, 47, 55, 27,  6, 33, 49, 53, 42, 57, 66, 71,
#        54,  3,  7, 64, 43, 31, 21, 65, 18, 41, 81,  1, 24, 39, 70,  2, 48,
#        38, 75, 10, 12, 20, 50, 77, 19,  8, 69, 68, 14,  4, 76, 15])

# %%
df_test[var].unique()
# Out:
# array([58,  8, 70, 47, 74, 79, 40, 35, 44, 71, 23, 69, 21, 78, 24, 60, 66,
#        52, 34, 57, 41, 56,  1, 25, 39, 31, 61, 22, 42, 33, 68, 26, 43, 53,
#        55, 64, 38,  5, 54, 72, 51, 20, 65, 16, 46, 67, 18,  2, 80, 37,  9,
#        28, 10, 82, 32, 30, 45, 50,  6, 73, 27, 63, 59, 29, 36, 48, 19, 77,
#        75, 15, 49, 14, 81, 13, 11, 62, 76,  4, 12,  7,  0,  3, 17])

# %% [markdown]
# For age, we rounded all values as integers to ensure the age values made sense.

# %% [markdown]
# # avg_glucose_level

# %%
var = 'avg_glucose_level'
df_train[var].unique()
# Out:
# array([ 65.87,  68.66, 170.93, ...,  80.13, 210.4 ,  86.94])

# %%
df_test[var].unique()
# Out:
# array([ 87.96, 110.89,  69.04, 210.95, 205.84,  77.08,  57.08,  95.04,
#         85.37,  57.33, 198.21, 149.75,  94.09, 203.04,  97.93,  78.05,
#         89.44, 243.5 ,  75.23,  66.42, 205.23,  78.4 , 137.96,  72.55,
#         99.8 ,  73.02,  88.11, 138.29,  83.51, 213.37, 122.41,  80.88,
#         93.48, 101.37, 105.22,  68.19,  74.44,  92.21, 100.09,  75.05,
#        184.15,  96.88,  79.14,  65.24, 111.19,  65.38,  96.99,  97.08,
#         88.78, 102.64,  70.92,  86.11, 129.16, 114.01,  98.41, 127.18,
#        105.61, 155.43,  75.29, 100.35, 247.69, 103.62, 144.1 , 114.25,
#         74.46, 118.51, 182.86,  89.99,  63.61,  60.53, 102.34, 111.43,
#        148.91,  69.4 ,  71.2 ,  92.04,  98.54, 112.43,  67.39,  98.42,
#        111.85,  92.39,  63.71,  70.35,  57.27,  57.57,  87.43,  81.18,
#         59.49,  56.75,  92.14,  92.11,  74.98,  55.25,  79.89,  94.26,
#         94.34,  99.82,  59.54,  89.63,  80.93, 200.49, 156.57,  80.4 ,
#         75.19, 103.51,  70.78,  84.11,  74.02,  78.49,  75.04, 128.97,
#         79.08, 106.51,  92.7 ,  82.59,  91.  ,  60.26, 122.74,  83.83,
#        212.01, 126.35,  88.66, 112.95,  76.82,  91.56, 109.1 , 121.04,
#        160.83,  85.62, 119.52,  89.3 ,  69.21, 126.18, 125.38,  73.01,
#        103.61, 160.  ,  86.96, 237.15,  90.92, 104.48,  70.71,  63.64,
#         87.27, 109.51,  57.82, 115.29, 111.02, 109.02,  87.11, 207.64,
#        100.97,  86.4 ,  61.81,  89.98,  98.58,  90.1 , 112.47, 195.03,
#         65.81, 123.36,  72.93,  84.27,  72.49,  82.61,  79.85, 131.77,
#         86.34, 156.18, 105.63,  84.08, 110.55,  84.93, 113.01, 115.52,
#        254.63,  96.63, 246.34, 195.16,  93.34,  69.7 ,  75.88,  89.45,
#        121.14,  88.65, 103.94,  56.3 ,  98.1 ,  71.73,  57.26, 195.04,
#         75.79,  82.31,  73.  , 138.07, 112.07,  83.56,  69.3 ,  75.62,
#        224.71, 122.75, 226.11,  82.57, 102.06,  65.59, 120.85,  62.68,
#        198.02,  85.35, 118.62,  93.11,  93.71,  76.25,  94.33,  57.89,
#        127.75, 108.03, 104.07,  74.72, 145.71, 167.31,  87.49,  74.82,
#         93.04,  85.82, 144.16,  67.97,  70.87, 199.96,  86.33,  78.85,
#        103.81, 155.17, 132.41, 103.25, 246.53,  87.72,  90.42, 107.29,
#        228.7 , 102.37,  86.26,  59.87,  72.76, 120.77,  60.39,  78.99,
#         83.84, 107.98, 216.88,  83.02, 139.43,  87.33, 124.08, 104.36,
#         81.28,  58.3 ,  97.5 ,  90.43, 110.47,  87.78, 126.67,  70.58,
#         65.29,  97.14, 237.17, 106.41,  93.58,  84.3 ,  61.42,  83.79,
#         75.94,  55.51,  58.29, 115.83,  99.69, 102.89,  79.05, 210.  ,
#        222.6 , 199.14, 191.48, 200.16,  80.73, 145.26, 103.35,  85.92,
#         80.8 ,  62.56,  71.38, 122.48,  86.87,  70.65, 105.73,  58.02,
#         56.84,  58.69,  92.32,  80.63,  84.9 ,  74.05,  71.81, 211.88,
#         56.67, 225.6 ,  70.93,  89.93,  84.85, 224.63, 110.53,  79.33,
#        213.87, 222.85,  72.65,  86.68, 217.11,  70.96,  83.26,  76.63,
#         74.26, 164.67,  92.73,  92.82,  59.99,  90.26,  91.9 , 149.9 ,
#        100.33,  75.53,  80.24,  65.95,  77.63,  75.5 ,  65.6 , 186.95,
#         68.66, 146.97, 198.24,  90.51,  80.74,  93.  ,  86.74,  91.46,
#         81.05,  73.27,  95.75, 120.25,  82.37, 114.45, 101.3 ,  94.98,
#         93.13,  82.13,  65.28,  94.47,  75.77,  88.97,  93.14,  65.34,
#         81.96,  73.5 ,  80.72, 109.97,  92.87, 113.05, 134.33, 208.78,
#        114.16, 220.36,  76.03,  72.29,  80.42,  93.64, 217.75,  58.7 ,
#        149.13,  82.39,  80.25, 170.76, 189.44,  70.03,  60.96,  83.91,
#        152.02,  60.61,  93.3 ,  97.39, 134.61,  56.9 , 112.66,  71.06,
#        133.82,  88.81,  94.12, 125.09,  96.04,  89.03,  56.34,  61.83,
#        131.99, 145.5 , 131.43,  75.64,  95.07,  87.16,  80.47,  65.01,
#        110.07,  90.35, 162.93,  89.22,  85.81, 206.52,  62.66, 100.49,
#         96.86,  74.43,  86.55,  61.34, 140.93,  86.  , 229.58,  65.66,
#        114.99,  77.37,  98.03, 117.34,  77.51,  64.15,  74.5 , 216.4 ,
#         74.7 ,  81.44, 100.61, 205.  ,  95.25, 101.15,  68.38, 113.87,
#         78.9 ,  59.61,  97.55,  82.15,  70.52,  88.29,  80.18,  82.27,
#         77.55,  87.84,  58.63, 150.1 ,  81.31,  90.4 , 209.5 ,  72.61,
#        206.15, 102.9 ,  97.97, 196.61,  79.55,  76.92, 120.94, 216.38,
#        105.74,  58.41,  83.16, 110.68,  70.06,  95.66,  66.08,  87.26,
#        146.59, 121.39,  78.97,  84.12, 153.6 ,  91.28, 190.13,  92.3 ,
#         84.46, 178.89, 227.74, 100.66, 213.8 ,  99.1 ,  57.47,  78.24,
#        103.43,  99.83, 190.92,  89.02,  93.62,  88.57,  89.11, 110.87,
#        142.68,  75.28, 100.75, 110.42,  95.88,  86.03, 227.96, 111.68,
#         99.29, 105.93, 107.83,  88.19,  84.6 ,  69.38,  65.42,  82.12,
#         96.01, 102.42, 125.3 , 141.8 ,  92.65,  57.02,  83.3 ,  89.53,
#        105.19,  68.79, 121.17,  82.18, 107.42, 111.78, 105.77,  77.53,
#        239.95,  83.33,  65.33, 202.21,  57.28,  58.42, 103.76,  70.73,
#        198.79,  96.52,  96.37,  73.89,  72.94,  68.48,  85.03,  95.36,
#        110.33,  65.16,  56.37,  87.1 ,  90.68,  62.52,  84.86, 215.81,
#        149.17, 139.48, 104.04, 112.46,  97.35,  80.55,  86.53, 114.61,
#         56.08, 102.46,  84.1 ,  65.07, 201.58, 211.12, 108.72,  61.87,
#        104.86,  76.21,  87.25,  62.91, 107.61, 228.2 ,  92.15,  83.7 ,
#        104.45, 223.9 ,  93.18, 207.96, 176.78,  90.65,  92.37, 127.23,
#        113.57,  91.85,  88.49,  78.32,  84.7 ,  72.6 ,  84.43,  84.13,
#         81.54,  90.97, 127.57,  98.9 , 114.32,  90.6 , 124.38,  79.25,
#         98.84, 228.92,  81.25,  76.81,  78.  , 263.56,  80.51,  87.87,
#        103.6 ,  85.59,  81.11,  67.06, 228.05, 119.9 , 105.51,  83.42,
#         62.69,  89.61, 111.81,  60.09,  91.02,  91.57,  62.57,  70.11,
#         75.46,  63.63,  94.25, 100.12, 205.97, 112.19, 193.87, 111.04,
#        214.77,  73.76, 197.11,  94.49,  98.22, 125.89,  65.12,  79.21,
#        202.98,  60.7 ,  92.22,  79.94,  69.92, 136.96, 226.38,  82.05,
#         61.11,  82.49,  83.15,  78.7 ,  99.23,  83.52, 226.84, 116.25,
#         88.38,  91.81, 115.4 , 200.73,  67.3 ,  89.16, 108.64,  81.21,
#        202.51, 126.04,  82.3 ,  70.22,  87.81, 142.31,  74.15,  61.53,
#        113.95,  78.23,  94.11,  87.5 ,  76.74, 138.55, 101.19, 145.94,
#         93.93,  86.21,  75.41,  95.28,  95.87,  62.61,  76.57,  92.71,
#         99.  ,  93.6 ,  57.42, 173.9 ,  60.57, 105.34, 122.73,  94.63,
#         56.85,  65.48,  72.53, 116.85, 117.04,  58.24,  82.53,  71.25,
#        129.73, 105.88, 217.94,  69.89,  87.2 ,  57.6 , 124.37, 102.39,
#         93.96,  92.49, 122.39, 107.58, 208.05,  85.16, 198.3 , 100.06,
#        103.11,  95.79, 117.63, 218.6 ,  77.5 , 119.77,  76.45,  95.8 ,
#        134.12,  82.62,  61.29,  98.92,  90.74, 159.79,  97.86,  91.58,
#        109.52, 104.55,  84.17,  67.28,  88.51,  90.38, 207.6 , 158.9 ,
#         69.52, 110.96,  89.32, 102.1 ,  57.59, 163.17, 212.62, 128.63,
#         77.6 , 120.15,  95.89,  89.06, 123.08,  60.64, 106.54,  72.04,
#        222.52,  92.74, 232.64,  73.24, 119.4 ,  88.79,  87.12,  56.33,
#         87.71, 207.37, 111.08, 201.96, 123.89,  90.44, 138.44,  75.06,
#        102.76, 131.05, 131.42,  69.46, 101.12, 116.06,  77.95,  67.56,
#        253.93, 207.84,  63.42,  79.57, 101.46, 134.76,  56.48, 228.5 ,
#         74.39, 118.55, 232.29, 236.04,  88.98,  86.85,  94.77,  85.18,
#         76.34,  83.8 , 112.37,  76.08, 108.51,  98.07,  99.01,  64.37,
#        146.1 , 192.5 ,  89.42,  82.26,  87.4 ,  86.95, 101.76,  57.4 ,
#         95.19,  89.41,  78.79,  70.13,  81.51,  86.07,  94.24,  89.73,
#        208.39,  77.76, 116.04,  92.75,  62.44, 108.82, 121.15,  87.  ,
#        135.82,  83.55,  68.07, 112.7 ,  74.34,  60.32, 200.25,  90.31,
#         76.43,  75.84,  81.33, 101.56, 244.3 ,  58.23,  59.67, 213.92,
#         79.81,  90.3 , 100.47,  66.46,  96.47,  60.13, 156.43,  73.07,
#         63.43,  74.88,  88.1 ,  74.16, 232.78,  89.57,  75.07, 106.65,
#         63.56,  79.66, 104.09, 174.54,  73.63,  98.52, 234.45,  87.54,
#         67.92,  97.65, 121.83,  81.53, 114.92, 165.36,  89.24,  63.82,
#         71.29, 119.58, 110.32, 137.27,  69.77,  71.4 ,  71.8 ,  75.22,
#        119.3 , 208.69,  81.87, 153.31, 231.72,  81.88, 110.84,  61.57,
#         67.55, 243.52, 108.63,  84.49,  73.71,  72.96,  82.19, 208.31,
#         98.61,  74.12,  71.08,  84.07, 132.88,  80.3 , 101.95,  99.76,
#        215.07,  83.37, 124.66,  82.64,  77.42, 117.59, 203.36,  84.04,
#         89.29, 179.38, 138.51,  61.98,  76.31,  95.05,  82.38,  91.68,
#        166.29,  76.15, 252.72,  84.03,  90.9 , 109.78, 196.71,  59.32,
#        185.17, 104.72, 104.47, 116.55, 228.56, 240.09, 101.45,  64.14,
#         78.92,  73.18, 224.1 ,  59.86, 263.32, 140.1 , 207.28, 199.2 ,
#        103.68,  70.28, 221.79, 151.16,  67.29, 221.89, 195.71, 111.98,
#         64.44, 112.24, 215.94,  93.81, 114.77,  74.11, 116.1 , 199.86,
#         60.98,  70.94,  86.3 ,  78.8 ,  87.8 ])

# %%
missing_values = df_train[var].isna().sum()

print(f"Number of missing values in {var}: {missing_values}")
# Out:
# Number of missing values in avg_glucose_level: 0

# %%
missing_values = df_test[var].isna().sum()

print(f"Number of missing values in {var}: {missing_values}")
# Out:
# Number of missing values in avg_glucose_level: 0

# %% [markdown]
# # bmi

# %%
var = 'bmi'
df_train[var].unique()
# Out:
# array([32.2, 25.3, 30.7, 27.1, 30.6, 30.4, 41.7, 22.3, 35.9, 33.8, 29.4,
#        28.9, 26.2, 22.5, 55.7, 26.1, 22.4, 33.2, 24.8, 20.9, 22. , 27.6,
#        35.8, 32.8, 15.9, 16.2, 41.3, 22.9, 19.5, 31.1, 31.9, 30.9, 15.7,
#        24.6, 18.6, 27.4, 25.6, 25.4, 25.5, 26.3, 35.2,  nan, 28.3, 32.3,
#        18.8, 33.7, 30.8, 41.1, 31.2, 33.3, 20.8, 19.4, 46.5, 28.7, 23.6,
#        31.7, 29.9, 26.7, 28.5, 29.3, 29.6, 19.2, 34.9, 32.4, 17.4, 36.1,
#        43.2, 20.2, 31.4, 30.2, 20.4, 30.5, 34.7, 26.5, 35.5, 33.9, 29.2,
#        24.9, 17.6, 23. , 19.8, 23.5, 32.7, 39.4, 35.3, 30.1, 27.2, 29. ,
#        36.6, 33.1, 38.4, 20. , 28.6, 23.9, 23.2, 23.7, 60.9, 22.1, 25.9,
#        26. , 31.5, 16.7, 31. , 43.6, 24.5, 32. , 35.1, 18.3, 44.7, 54.7,
#        39.7, 26.4, 34.3, 17.7, 32.1, 35.7, 40.1, 16.9, 35. , 38.1, 71.9,
#        43.7, 19.1, 26.6, 17.9, 27.9, 25.8, 21. , 28.8, 49.3, 37.2, 23.1,
#        40.5, 35.6, 20.7, 34. , 36.4, 20.1, 37.3, 22.2, 17.3, 28. , 25. ,
#        21.8, 28.1, 39.2, 32.6, 25.1, 41.2, 26.9, 24.1, 38.5, 33.6, 17. ,
#        33.4, 18.1, 34.8, 30.3, 16. , 29.5, 18.2, 27.8, 39. , 24.3, 21.9,
#        37.8, 23.4, 22.8, 21.1, 24.7, 43.9, 21.5, 22.6, 20.3, 18.4, 38.6,
#        19. , 57.2, 33. , 29.1, 48.8, 16.4, 21.4, 29.8, 17.2, 45. , 13.7,
#        38. , 15.6, 31.8, 43. , 24. , 42.3, 16.6, 23.8, 44.8, 27.3, 20.6,
#        37.9, 34.5, 24.2, 27. , 18.5, 21.3, 30. , 37. , 36.2, 31.6, 16.3,
#        14.1, 18.7, 36.7, 47.6, 39.9, 43.8, 27.7, 42.1, 14.4, 29.7, 36.9,
#        39.1, 26.8, 44. , 38.8, 23.3, 40.4, 35.4, 14.3, 21.6, 37.4, 51. ,
#        13.8, 33.5, 19.3, 28.2, 53.9, 27.5, 15.5, 28.4, 13.3, 20.5, 46.4,
#        52.3, 34.1, 32.9, 36.3, 41.8, 25.7, 14.6, 42.2, 31.3, 25.2, 38.9,
#        45.8, 54. , 12. , 34.2, 19.7, 53.8, 16.8, 17.8, 41.6, 22.7, 59.7,
#        40.3, 18. , 55.2, 34.4, 37.6, 41.5, 18.9, 41. , 42.4, 40.2, 15.4,
#        37.1, 50.5, 43.3, 78. , 54.1, 16.1, 19.6, 42.8, 42.5, 17.1, 34.6,
#        36.8, 24.4, 37.7, 17.5, 45.1, 21.2, 46. , 44.5, 49.5, 32.5, 14. ,
#        40.7, 45.3, 15.8, 42.7, 48.2, 40.8, 36. , 37.5, 57.7, 36.5, 48.5,
#        50.3, 13.5, 50.2, 14.8, 39.8, 38.2, 40. , 45.2, 38.3, 55.9, 60.2,
#        46.9, 49.8, 21.7, 19.9, 40.9, 43.1, 15.3, 39.5, 53.5, 39.6, 48. ,
#        52.8, 56. , 47.5, 15.2, 42. , 15.1, 56.1, 50.9, 14.9, 52.9, 51.5,
#        48.7, 38.7, 13.4, 57.9, 46.8, 47.3, 92. , 44.9, 42.9, 52.7, 66.8,
#        39.3, 16.5, 43.4, 12.8, 50.6, 52.5, 54.2, 51.8, 64.4, 14.2, 49.4,
#        44.4, 51.7, 42.6, 45.4, 12.3, 48.3, 47.8, 56.6, 97.6, 48.4, 14.5,
#        55. , 41.9, 41.4, 44.6, 55.1, 47.1, 49.2, 44.3, 45.5, 48.9, 46.2,
#        13. , 44.2, 57.3, 15. , 46.1, 13.2, 61.2, 50.8, 61.6, 63.3, 10.3,
#        53.4, 54.8, 11.3, 46.3, 46.6, 45.9, 44.1, 45.7])

# %%
df_test[var].unique()
# Out:
# array([39.2, 17.6, 35.9, 50.1, 54.6, 35. , 22. , 42.4, 33. , 24.6, 27.3,
#        27. , 30.9, 33.6, 31.2, 25.7, 21.9, 26.1, 29. , 23.6, 39.5, 64.8,
#        35.1, 21. , 31.6, 31.1, 15.5, 26.4, 36. , 40.3, 23.8, 23.7, 37.9,
#        31. , 45.2, 27.4, 22.9,  nan, 31.4, 25. , 28.9, 39.7, 41.2, 34.8,
#        31.7, 35.8, 28.3, 41.6, 19. , 32.4, 31.8, 32.1, 26.7, 27.9, 22.6,
#        28.1, 40.9, 27.6, 24.3, 35.6, 40.6, 24.4, 42.3, 17.5, 17. , 47.8,
#        27.1, 23.1, 30.2, 36.4, 22.1, 40.5, 23. , 28. , 22.8, 55.7, 26.9,
#        18.3, 36.2, 21.4, 20.4, 34.2, 42.2, 23.2, 34.6, 28.4, 57.5, 37. ,
#        20.3, 22.3, 24.5, 23.5, 40.2, 29.5, 26.2, 33.3, 24.2, 23.3, 30.3,
#        25.2, 36.7, 22.2, 20. , 17.8, 46.1, 33.1, 18.1, 24.8, 31.9, 25.8,
#        27.7, 29.1, 30.1, 31.3, 19.5, 28.8, 32.9, 22.4, 19.8, 30.5, 42.6,
#        37.1, 18.7, 32.8, 28.7, 32.3, 33.4, 44.9, 28.5, 45. , 25.3, 28.2,
#        37.6, 34.4, 26.5, 21.1, 30. , 19.7, 21.8, 45.5, 21.3, 20.1, 25.1,
#        42.9, 14.3, 16.2, 38.7, 29.7, 14.6, 27.2, 19.3, 26.6, 30.6, 41.9,
#        26. , 28.6, 33.9, 35.5, 16.3, 34. , 24. , 16.9, 16.4, 40.4, 34.3,
#        41.1, 33.2, 36.3, 24.7, 55.9, 20.8, 44. , 18.5, 25.5, 37.2, 40.1,
#        37.3, 44.8, 43.2, 29.9, 22.5, 43. , 21.6, 25.4, 42.8, 15.2, 29.4,
#        25.6, 33.8, 27.8, 36.1, 32.7, 23.4, 34.9, 33.5, 38.1, 38.5, 30.7,
#        43.9, 38. , 32.5, 39.4, 41.3, 41.5, 38.9, 17.1, 11.5, 23.9, 44.2,
#        35.7, 14.2, 15.4, 29.2, 27.5, 37.5, 38.8, 30.4, 20.6, 15.7, 53.8,
#        18.6, 35.4, 20.2, 29.8, 19.1, 46.5, 24.1, 18.8, 32. , 31.5, 36.6,
#        52.8, 35.3, 15.8, 34.5, 26.8, 19.9, 19.4, 15.3, 20.7, 14.8, 43.6,
#        22.7, 51.9, 32.6, 21.2, 16.1, 42.7, 36.8, 32.2, 39.3, 24.9, 21.7,
#        20.9, 30.8, 25.9, 48.3, 38.2, 58.1, 34.7, 15.1, 21.5, 37.7, 50.4,
#        26.3, 43.4, 19.6, 29.3, 53.4, 41. , 15. , 16.6, 40.8, 47.4, 19.2,
#        43.3, 35.2, 20.5, 16. , 39.1, 16.5, 49.9, 39.9, 54.3, 47.9, 36.9,
#        17.3, 13.9, 17.4, 17.7, 17.2, 38.4, 18.4, 29.6, 44.6, 50.2, 39.6,
#        48.1, 37.8, 16.7, 45.7, 18. , 34.1, 46. , 16.8, 36.5, 56.6, 37.4])

# %%
missing_values = df_train[var].isna().sum()

print(f"Number of missing values in {var}: {missing_values}")
# Out:
# Number of missing values in bmi: 159

# %%
missing_values = df_test[var].isna().sum()

print(f"Number of missing values in {var}: {missing_values}")
# Out:
# Number of missing values in bmi: 42

# %% [markdown]
# # ever_married

# %%
var = 'ever_married'
df_train[var].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df_test[var].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# # gender

# %%
var = 'gender'
df_train[var].unique()
# Out:
# array(['Male', 'Female', 'Other'], dtype=object)

# %%
df_test[var].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
var = 'gender'
df_test[var].value_counts()
# Out:
# Female    596
# Male      427
# Name: gender, dtype: int64

# %%
df_test.loc[df_test[var] == "Other", var] = np.nan
df_train.loc[df_train[var] == 'Other', var] = np.nan

# %% [markdown]
# For gender, we replaced Other values with nan.

# %% [markdown]
# # heart_disease

# %%
var = 'heart_disease'
df_train[var].unique()
# Out:
# array([0, 1])

# %%
df_test[var].unique()
# Out:
# array([0, 1])

# %% [markdown]
# # hypertension

# %%
var = 'hypertension'
df_train[var].unique()
# Out:
# array([0, 1])

# %%
df_test[var].unique()
# Out:
# array([1, 0])

# %% [markdown]
# # id

# %%
var = 'id'
df_train[var].unique()
# Out:
# array([68685, 59058, 46068, ..., 37060, 29552, 14499])

# %%
df_test[var].unique()
# Out:
# array([30468, 16523, 56543, ..., 28493, 27153, 34060])

# %%
missing_values = df_train[var].isna().sum()

print(f"Number of missing values in {var}: {missing_values}")
# Out:
# Number of missing values in id: 0

# %%
missing_values = df_test[var].isna().sum()

print(f"Number of missing values in {var}: {missing_values}")
# Out:
# Number of missing values in id: 0

# %% [markdown]
# # Residence_type

# %%
var = 'Residence_type'
df_train[var].unique()
# Out:
# array(['Urban', 'Rural'], dtype=object)

# %%
df_test[var].unique()
# Out:
# array(['Urban', 'Rural'], dtype=object)

# %% [markdown]
# # smoking_status

# %%
var = 'smoking_status'
df_train[var].unique()
# Out:
# array(['formerly smoked', 'never smoked', 'Unknown', 'smokes'],
#       dtype=object)

# %%
df_test[var].unique()
# Out:
# array(['never smoked', 'Unknown', 'formerly smoked', 'smokes'],
#       dtype=object)

# %%
df_train.loc[df_train[var] == "never smoked", var] = "Non-Smoker"
df_train.loc[df_train[var] == "Unknown", var] = np.nan
df_train.loc[df_train[var] == "formerly smoked", var] = "Previous Smoker"
df_train.loc[df_train[var] == "smokes", var] = "Current Smoker"

# %%
df_test.loc[df_test[var] == "never smoked", var] = "Non-Smoker"
df_test.loc[df_test[var] == "Unknown", var] = np.nan
df_test.loc[df_test[var] == "formerly smoked", var] = "Previous Smoker"
df_test.loc[df_test[var] == "smokes", var] = "Current Smoker"

# %%
df_train[var].unique()
# Out:
# array(['Previous Smoker', 'Non-Smoker', nan, 'Current Smoker'],
#       dtype=object)

# %%
df_test[var].unique()
# Out:
# array(['Non-Smoker', nan, 'Previous Smoker', 'Current Smoker'],
#       dtype=object)

# %% [markdown]
# For smoking_status, we cleaned up the labels of the unique values and replaced Unknown values with nan.

# %% [markdown]
# # work_type

# %%
var = 'work_type'
df_train[var].unique()
# Out:
# array(['Govt_job', 'Self-employed', 'Private', 'children', 'Never_worked'],
#       dtype=object)

# %%
df_test[var].unique()
# Out:
# array(['Private', 'Self-employed', 'Govt_job', 'children', 'Never_worked'],
#       dtype=object)

# %%
df_train.loc[df_train[var] == "Private", var] = "Private Sector"
df_train.loc[df_train[var] == "Govt_job", var] = "Public Sector"
df_train.loc[df_train[var] == "children", var] = "Homemaker"
df_train.loc[df_train[var] == "Never_worked", var] = "Unemployed"

# %%
df_test.loc[df_test[var] == "Private", var] = "Private Sector"
df_test.loc[df_test[var] == "Govt_job", var] = "Public Sector"
df_test.loc[df_test[var] == "children", var] = "Homemaker"
df_test.loc[df_test[var] == "Never_worked", var] = "Unemployed"

# %%
df_train[var].unique()
# Out:
# array(['Public Sector', 'Self-employed', 'Private Sector', 'Homemaker',
#        'Unemployed'], dtype=object)

# %%
df_test[var].unique()
# Out:
# array(['Private Sector', 'Self-employed', 'Public Sector', 'Homemaker',
#        'Unemployed'], dtype=object)

# %% [markdown]
# For work_type, we cleaned up the labels of the unique values.

# %% [markdown]
# # stroke

# %%
var = 'stroke'
df_train[var].unique()
# Out:
# array([0, 1])

# %%
df_test[var].unique()
# Out:
# array([0, 1])

# %% [markdown]
# # **Data Visualization (Testing Data)**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set up the matplotlib figure
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(10, 12))

# Plot age
sns.histplot(df_test['age'], kde=True, ax=axes[0], bins=30, color='skyblue')
axes[0].set_title('Age Distribution')

# Plot avg_glucose_level
sns.histplot(df_test['avg_glucose_level'], kde=True, ax=axes[1], bins=30, color='salmon')
axes[1].set_title('Average Glucose Level Distribution')

# Plot bmi
sns.histplot(df_test['bmi'].dropna(), kde=True, ax=axes[2], bins=30, color='green')
axes[2].set_title('BMI Distribution')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Bar plot for ever_married
plt.figure(figsize=(8, 6))
sns.countplot(x='ever_married', data=df_test, palette='pastel')
plt.title('Ever Married Distribution')
plt.show()

# Bar plot for gender
plt.figure(figsize=(8, 6))
sns.countplot(x='gender', data=df_test, palette='pastel')
plt.title('Gender Distribution')
plt.show()

# Bar plot for heart_disease
plt.figure(figsize=(8, 6))
sns.countplot(x='heart_disease', data=df_test, palette='pastel')
plt.title('Heart Disease Distribution')
plt.show()

# Bar plot for hypertension
plt.figure(figsize=(8, 6))
sns.countplot(x='hypertension', data=df_test, palette='pastel')
plt.title('Hypertension Distribution')
plt.show()

# Bar plot for Residence_type
plt.figure(figsize=(8, 6))
sns.countplot(x='Residence_type', data=df_test, palette='pastel')
plt.title('Residence Type Distribution')
plt.show()

# Bar plot for smoking_status
plt.figure(figsize=(8, 6))
sns.countplot(x='smoking_status', data=df_test, palette='pastel')
plt.title('Smoking Status Distribution')
plt.show()

# Bar plot for work_type
plt.figure(figsize=(10, 6))
sns.countplot(x='work_type', data=df_test, palette='pastel')
plt.title('Work Type Distribution')
plt.xticks(rotation=45, ha='right')
plt.show()

# Bar plot for stroke
plt.figure(figsize=(8, 6))
sns.countplot(x='stroke', data=df_test, palette='pastel')
plt.title('Stroke Distribution')
plt.show()

# %% [markdown]
# # **Data Visualization (Training Data)**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set up the matplotlib figure
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(10, 12))

# Plot age
sns.histplot(df_train['age'], kde=True, ax=axes[0], bins=30, color='skyblue')
axes[0].set_title('Age Distribution')

# Plot avg_glucose_level
sns.histplot(df_train['avg_glucose_level'], kde=True, ax=axes[1], bins=30, color='salmon')
axes[1].set_title('Average Glucose Level Distribution')

# Plot bmi
sns.histplot(df_train['bmi'].dropna(), kde=True, ax=axes[2], bins=30, color='green')
axes[2].set_title('BMI Distribution')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Bar plot for ever_married
plt.figure(figsize=(8, 6))
sns.countplot(x='ever_married', data=df_train, palette='pastel')
plt.title('Ever Married Distribution')
plt.show()

# Bar plot for gender
plt.figure(figsize=(8, 6))
sns.countplot(x='gender', data=df_train, palette='pastel')
plt.title('Gender Distribution')
plt.show()

# Bar plot for heart_disease
plt.figure(figsize=(8, 6))
sns.countplot(x='heart_disease', data=df_train, palette='pastel')
plt.title('Heart Disease Distribution')
plt.show()

# Bar plot for hypertension
plt.figure(figsize=(8, 6))
sns.countplot(x='hypertension', data=df_train, palette='pastel')
plt.title('Hypertension Distribution')
plt.show()

# Bar plot for Residence_type
plt.figure(figsize=(8, 6))
sns.countplot(x='Residence_type', data=df_train, palette='pastel')
plt.title('Residence Type Distribution')
plt.show()

# Bar plot for smoking_status
plt.figure(figsize=(8, 6))
sns.countplot(x='smoking_status', data=df_train, palette='pastel')
plt.title('Smoking Status Distribution')
plt.show()

# Bar plot for work_type
plt.figure(figsize=(10, 6))
sns.countplot(x='work_type', data=df_train, palette='pastel')
plt.title('Work Type Distribution')
plt.xticks(rotation=45, ha='right')
plt.show()

# Bar plot for stroke
plt.figure(figsize=(8, 6))
sns.countplot(x='stroke', data=df_train, palette='pastel')
plt.title('Stroke Distribution')
plt.show()

# %% [markdown]
# # **Simple Modeling**

# %% [markdown]
# # Simple Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

df_train_encoded = pd.get_dummies(df_train, columns=['Residence_type', 'gender', 'work_type', 'ever_married', 'smoking_status'], drop_first=True)
df_test_encoded = pd.get_dummies(df_test, columns=['Residence_type', 'gender', 'work_type', 'ever_married', 'smoking_status'], drop_first=True)
df_train_encoded = df_train_encoded.dropna()
df_test_encoded = df_test_encoded.dropna()

X_train = df_train_encoded.drop('stroke', axis=1)
y_train = df_train_encoded['stroke']

X_test = df_train_encoded.drop('stroke', axis=1)
y_test = df_train_encoded['stroke']

model = LinearRegression()

# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model's performance
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
# Out:
# Mean Squared Error: 0.03382511347140212
# R-squared: 0.1876467637468272

# %%
df_test.head()
# Out:
#    Unnamed: 0     id  gender  age  hypertension  heart_disease ever_married  \
# 0         251  30468    Male   58             1              0          Yes
# 1         252  16523  Female    8             0              0           No
# 2         253  56543  Female   70             0              0          Yes
# 3         255  32257  Female   47             0              0          Yes
# 4         259  28674  Female   74             1              0          Yes
#
#         work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0  Private Sector          Urban              87.96  39.2       Non-Smoker
# 1  Private Sector          Urban             110.89  17.6              NaN
# 2  Private Sector          Rural              69.04  35.9  Previous Smoker
# 3  Private Sector          Urban             210.95  50.1              NaN
# 4   Self-employed          Urban             205.84  54.6       Non-Smoker
#
#    stroke
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
from sklearn.preprocessing import PolynomialFeatures

df_train_clean = df_train.dropna()
df_test_clean = df_test.dropna()

count = 10
arr = [0]*count
arr2 = [0]*count
vars = ['age', 'hypertension',	'heart_disease', 'avg_glucose_level',	'bmi']
X_train_numeric = df_train_clean.loc[:,vars]
X_test_numeric = df_test_clean.loc[:,vars]



vars2 = ['Residence_type', 'gender', 'work_type', 'ever_married', 'smoking_status']
X_train_catigorical = df_train_clean.loc[:,vars2]
X_test_catigorical = df_test_clean.loc[:,vars2]


for i in range(count):
  degree = i+1

  poly = PolynomialFeatures(degree=degree, include_bias=False)
  X_train_numerical_poly = poly.fit_transform(X_train_numeric)
  X_test_numerical_poly = poly.fit_transform(X_test_numeric)

  X_train_combined = pd.concat([pd.DataFrame(X_train_numerical_poly, columns=poly.get_feature_names_out(vars)), X_train_catigorical.reset_index(drop=True)], axis=1)
  X_test_combined = pd.concat([pd.DataFrame(X_test_numerical_poly, columns=poly.get_feature_names_out(vars)), X_test_catigorical.reset_index(drop=True)], axis=1)


  X_train = pd.get_dummies(X_train_combined, columns=vars2, drop_first=True)
  X_test = pd.get_dummies(X_test_combined, columns=vars2, drop_first=True)


  y_train = df_train_clean['stroke']
  y_test = df_test_clean['stroke']

  model = LinearRegression()

  # Fit the model to the training data
  model.fit(X_train, y_train)

  # Make predictions on the test set
  y_pred = model.predict(X_test)

  # Evaluate the model's performance
  mse = mean_squared_error(y_test, y_pred)
  r2 = r2_score(y_test, y_pred)
  arr[i] = r2
  arr2[i] = mse

# %%
# Extract x and y coordinates from the subset
x = arr

y = [0]*count
for i in range(count):
  y[i] = i+1

# Create a scatter plot
plt.scatter(y, x, label='degree vs r^2', color='blue')
plt.xlabel('degree')
plt.ylabel('r^2')
plt.title('degree vs r^2')
plt.legend()
plt.show()

# %%
# Only show positive elements
x = arr[:3]

y = [0]*len(x)
for i in range(len(x)):
    y[i] = i+1

# Create a scatter plot
plt.scatter(y, x, label='degree vs r^2', color='blue')
plt.xlabel('degree')
plt.ylabel('r^2')
plt.title('degree vs r^2')
plt.legend()
plt.show()

# %%
# Positive R-squared values

print(x[0])
print(x[1])
print(x[2])
# Out:
# 0.07041445431403548
# 0.068388317076568
# 0.01449644532770844

# %%
# best r-sq value so far is 0.187

# %% [markdown]
# ## Regression Tree

# %%
from sklearn import tree
import math
from sklearn.metrics import r2_score

X_train = df_train_encoded.drop(['stroke', 'Unnamed: 0', 'id'], axis=1)
y_train = df_train_encoded['stroke']

X_test = df_test_encoded.drop(['stroke', 'Unnamed: 0', 'id'], axis=1)
y_test = df_test_encoded['stroke']

regtree = tree.DecisionTreeRegressor()
regtree.fit(X_train, y_train)

tree.plot_tree(regtree, filled=True)
# Out:
# [Text(151.19854883292385, 212.91, 'X[0] <= 66.5\nmse = 0.042\nsamples = 3928\nvalue = 0.044'),
#  Text(60.088682432432435, 203.85, 'X[0] <= 48.5\nmse = 0.02\nsamples = 3262\nvalue = 0.021'),
#  Text(18.714250614250616, 194.79, 'X[0] <= 37.5\nmse = 0.005\nsamples = 2194\nvalue = 0.005'),
#  Text(6.580835380835381, 185.73, 'X[3] <= 57.935\nmse = 0.001\nsamples = 1569\nvalue = 0.001'),
#  Text(3.2904176904176907, 176.67, 'X[3] <= 57.925\nmse = 0.024\nsamples = 40\nvalue = 0.025'),
#  Text(1.6452088452088454, 167.60999999999999, 'mse = 0.0\nsamples = 39\nvalue = 0.0'),
#  Text(4.935626535626536, 167.60999999999999, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(9.871253071253072, 176.67, 'X[0] <= 31.5\nmse = 0.001\nsamples = 1529\nvalue = 0.001'),
#  Text(8.226044226044227, 167.60999999999999, 'mse = 0.0\nsamples = 1236\nvalue = 0.0'),
#  Text(11.516461916461918, 167.60999999999999, 'X[0] <= 32.5\nmse = 0.003\nsamples = 293\nvalue = 0.003'),
#  Text(9.871253071253072, 158.55, 'X[3] <= 76.645\nmse = 0.018\nsamples = 56\nvalue = 0.018'),
#  Text(8.226044226044227, 149.49, 'X[3] <= 75.165\nmse = 0.059\nsamples = 16\nvalue = 0.062'),
#  Text(6.580835380835381, 140.43, 'mse = 0.0\nsamples = 15\nvalue = 0.0'),
#  Text(9.871253071253072, 140.43, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(11.516461916461918, 149.49, 'mse = 0.0\nsamples = 40\nvalue = 0.0'),
#  Text(13.161670761670763, 158.55, 'mse = 0.0\nsamples = 237\nvalue = 0.0'),
#  Text(30.84766584766585, 185.73, 'X[3] <= 97.77\nmse = 0.016\nsamples = 625\nvalue = 0.016'),
#  Text(27.145945945945947, 176.67, 'X[3] <= 97.675\nmse = 0.024\nsamples = 361\nvalue = 0.025'),
#  Text(25.500737100737105, 167.60999999999999, 'X[3] <= 82.26\nmse = 0.022\nsamples = 360\nvalue = 0.022'),
#  Text(19.742506142506144, 158.55, 'X[1] <= 0.5\nmse = 0.01\nsamples = 208\nvalue = 0.01'),
#  Text(14.806879606879608, 149.49, 'X[3] <= 78.145\nmse = 0.005\nsamples = 194\nvalue = 0.005'),
#  Text(13.161670761670763, 140.43, 'mse = 0.0\nsamples = 152\nvalue = 0.0'),
#  Text(16.452088452088454, 140.43, 'X[3] <= 78.21\nmse = 0.023\nsamples = 42\nvalue = 0.024'),
#  Text(14.806879606879608, 131.37, 'X[11] <= 0.5\nmse = 0.25\nsamples = 2\nvalue = 0.5'),
#  Text(13.161670761670763, 122.30999999999999, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(16.452088452088454, 122.30999999999999, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(18.0972972972973, 131.37, 'mse = 0.0\nsamples = 40\nvalue = 0.0'),
#  Text(24.67813267813268, 149.49, 'X[3] <= 59.54\nmse = 0.066\nsamples = 14\nvalue = 0.071'),
#  Text(23.032923832923835, 140.43, 'X[3] <= 57.515\nmse = 0.222\nsamples = 3\nvalue = 0.333'),
#  Text(21.38771498771499, 131.37, 'mse = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(24.67813267813268, 131.37, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(26.323341523341526, 140.43, 'mse = 0.0\nsamples = 11\nvalue = 0.0'),
#  Text(31.258968058968062, 158.55, 'X[3] <= 82.3\nmse = 0.038\nsamples = 152\nvalue = 0.039'),
#  Text(29.613759213759216, 149.49, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(32.90417690417691, 149.49, 'X[3] <= 84.255\nmse = 0.032\nsamples = 151\nvalue = 0.033'),
#  Text(29.613759213759216, 140.43, 'X[3] <= 84.15\nmse = 0.106\nsamples = 25\nvalue = 0.12'),
#  Text(27.96855036855037, 131.37, 'X[4] <= 26.7\nmse = 0.076\nsamples = 24\nvalue = 0.083'),
#  Text(26.323341523341526, 122.30999999999999, 'X[4] <= 25.35\nmse = 0.16\nsamples = 10\nvalue = 0.2'),
#  Text(24.67813267813268, 113.24999999999999, 'mse = 0.0\nsamples = 8\nvalue = 0.0'),
#  Text(27.96855036855037, 113.24999999999999, 'mse = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(29.613759213759216, 122.30999999999999, 'mse = 0.0\nsamples = 14\nvalue = 0.0'),
#  Text(31.258968058968062, 131.37, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(36.1945945945946, 140.43, 'X[13] <= 0.5\nmse = 0.016\nsamples = 126\nvalue = 0.016'),
#  Text(34.54938574938575, 131.37, 'mse = 0.0\nsamples = 101\nvalue = 0.0'),
#  Text(37.83980343980345, 131.37, 'X[0] <= 46.5\nmse = 0.074\nsamples = 25\nvalue = 0.08'),
#  Text(34.54938574938575, 122.30999999999999, 'X[3] <= 93.29\nmse = 0.042\nsamples = 23\nvalue = 0.043'),
#  Text(32.90417690417691, 113.24999999999999, 'mse = 0.0\nsamples = 21\nvalue = 0.0'),
#  Text(36.1945945945946, 113.24999999999999, 'X[5] <= 0.5\nmse = 0.25\nsamples = 2\nvalue = 0.5'),
#  Text(34.54938574938575, 104.19, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(37.83980343980345, 104.19, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(41.13022113022113, 122.30999999999999, 'X[3] <= 88.995\nmse = 0.25\nsamples = 2\nvalue = 0.5'),
#  Text(39.48501228501229, 113.24999999999999, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(42.77542997542998, 113.24999999999999, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(28.791154791154796, 167.60999999999999, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(34.54938574938575, 176.67, 'X[4] <= 45.6\nmse = 0.004\nsamples = 264\nvalue = 0.004'),
#  Text(32.90417690417691, 167.60999999999999, 'mse = 0.0\nsamples = 245\nvalue = 0.0'),
#  Text(36.1945945945946, 167.60999999999999, 'X[4] <= 46.05\nmse = 0.05\nsamples = 19\nvalue = 0.053'),
#  Text(34.54938574938575, 158.55, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(37.83980343980345, 158.55, 'mse = 0.0\nsamples = 18\nvalue = 0.0'),
#  Text(101.46311425061425, 194.79, 'X[3] <= 96.11\nmse = 0.049\nsamples = 1068\nvalue = 0.051'),
#  Text(65.85976658476659, 185.73, 'X[11] <= 0.5\nmse = 0.029\nsamples = 565\nvalue = 0.03'),
#  Text(51.00147420147421, 176.67, 'X[4] <= 37.3\nmse = 0.065\nsamples = 43\nvalue = 0.07'),
#  Text(47.71105651105651, 167.60999999999999, 'X[3] <= 92.22\nmse = 0.028\nsamples = 35\nvalue = 0.029'),
#  Text(46.06584766584767, 158.55, 'mse = 0.0\nsamples = 30\nvalue = 0.0'),
#  Text(49.35626535626536, 158.55, 'X[4] <= 31.85\nmse = 0.16\nsamples = 5\nvalue = 0.2'),
#  Text(47.71105651105651, 149.49, 'mse = 0.0\nsamples = 4\nvalue = 0.0'),
#  Text(51.00147420147421, 149.49, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(54.29189189189189, 167.60999999999999, 'X[4] <= 37.9\nmse = 0.188\nsamples = 8\nvalue = 0.25'),
#  Text(52.64668304668305, 158.55, 'mse = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(55.93710073710074, 158.55, 'mse = 0.0\nsamples = 6\nvalue = 0.0'),
#  Text(80.71805896805897, 176.67, 'X[1] <= 0.5\nmse = 0.026\nsamples = 522\nvalue = 0.027'),
#  Text(69.30442260442261, 167.60999999999999, 'X[2] <= 0.5\nmse = 0.021\nsamples = 462\nvalue = 0.022'),
#  Text(61.28402948402949, 158.55, 'X[6] <= 0.5\nmse = 0.018\nsamples = 436\nvalue = 0.018'),
#  Text(54.29189189189189, 149.49, 'X[3] <= 64.285\nmse = 0.011\nsamples = 269\nvalue = 0.011'),
#  Text(51.00147420147421, 140.43, 'X[3] <= 63.975\nmse = 0.043\nsamples = 44\nvalue = 0.045'),
#  Text(49.35626535626536, 131.37, 'X[0] <= 49.5\nmse = 0.023\nsamples = 43\nvalue = 0.023'),
#  Text(47.71105651105651, 122.30999999999999, 'X[12] <= 0.5\nmse = 0.16\nsamples = 5\nvalue = 0.2'),
#  Text(46.06584766584767, 113.24999999999999, 'mse = 0.0\nsamples = 4\nvalue = 0.0'),
#  Text(49.35626535626536, 113.24999999999999, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(51.00147420147421, 122.30999999999999, 'mse = 0.0\nsamples = 38\nvalue = 0.0'),
#  Text(52.64668304668305, 131.37, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(57.58230958230959, 140.43, 'X[3] <= 92.965\nmse = 0.004\nsamples = 225\nvalue = 0.004'),
#  Text(55.93710073710074, 131.37, 'mse = 0.0\nsamples = 196\nvalue = 0.0'),
#  Text(59.22751842751843, 131.37, 'X[3] <= 92.985\nmse = 0.033\nsamples = 29\nvalue = 0.034'),
#  Text(57.58230958230959, 122.30999999999999, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(60.872727272727275, 122.30999999999999, 'mse = 0.0\nsamples = 28\nvalue = 0.0'),
#  Text(68.27616707616708, 149.49, 'X[4] <= 21.3\nmse = 0.029\nsamples = 167\nvalue = 0.03'),
#  Text(64.16314496314497, 140.43, 'X[3] <= 77.445\nmse = 0.222\nsamples = 3\nvalue = 0.333'),
#  Text(62.517936117936124, 131.37, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(65.80835380835381, 131.37, 'mse = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(72.3891891891892, 140.43, 'X[3] <= 84.875\nmse = 0.024\nsamples = 164\nvalue = 0.024'),
#  Text(69.0987714987715, 131.37, 'X[12] <= 0.5\nmse = 0.01\nsamples = 104\nvalue = 0.01'),
#  Text(67.45356265356266, 122.30999999999999, 'mse = 0.0\nsamples = 73\nvalue = 0.0'),
#  Text(70.74398034398035, 122.30999999999999, 'X[4] <= 29.15\nmse = 0.031\nsamples = 31\nvalue = 0.032'),
#  Text(69.0987714987715, 113.24999999999999, 'X[4] <= 28.35\nmse = 0.083\nsamples = 11\nvalue = 0.091'),
#  Text(67.45356265356266, 104.19, 'mse = 0.0\nsamples = 10\nvalue = 0.0'),
#  Text(70.74398034398035, 104.19, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(72.3891891891892, 113.24999999999999, 'mse = 0.0\nsamples = 20\nvalue = 0.0'),
#  Text(75.6796068796069, 131.37, 'X[3] <= 85.04\nmse = 0.048\nsamples = 60\nvalue = 0.05'),
#  Text(74.03439803439804, 122.30999999999999, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(77.32481572481574, 122.30999999999999, 'X[3] <= 87.855\nmse = 0.033\nsamples = 59\nvalue = 0.034'),
#  Text(75.6796068796069, 113.24999999999999, 'X[3] <= 87.68\nmse = 0.099\nsamples = 18\nvalue = 0.111'),
#  Text(74.03439803439804, 104.19, 'X[13] <= 0.5\nmse = 0.055\nsamples = 17\nvalue = 0.059'),
#  Text(72.3891891891892, 95.13, 'mse = 0.0\nsamples = 11\nvalue = 0.0'),
#  Text(75.6796068796069, 95.13, 'X[0] <= 57.5\nmse = 0.139\nsamples = 6\nvalue = 0.167'),
#  Text(74.03439803439804, 86.07, 'mse = 0.0\nsamples = 4\nvalue = 0.0'),
#  Text(77.32481572481574, 86.07, 'X[4] <= 33.15\nmse = 0.25\nsamples = 2\nvalue = 0.5'),
#  Text(75.6796068796069, 77.00999999999999, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(78.97002457002458, 77.00999999999999, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(77.32481572481574, 104.19, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(78.97002457002458, 113.24999999999999, 'mse = 0.0\nsamples = 41\nvalue = 0.0'),
#  Text(77.32481572481574, 158.55, 'X[0] <= 58.5\nmse = 0.071\nsamples = 26\nvalue = 0.077'),
#  Text(75.6796068796069, 149.49, 'mse = 0.0\nsamples = 16\nvalue = 0.0'),
#  Text(78.97002457002458, 149.49, 'X[0] <= 61.0\nmse = 0.16\nsamples = 10\nvalue = 0.2'),
#  Text(77.32481572481574, 140.43, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(80.61523341523342, 140.43, 'X[8] <= 0.5\nmse = 0.099\nsamples = 9\nvalue = 0.111'),
#  Text(78.97002457002458, 131.37, 'mse = 0.0\nsamples = 6\nvalue = 0.0'),
#  Text(82.26044226044226, 131.37, 'X[5] <= 0.5\nmse = 0.222\nsamples = 3\nvalue = 0.333'),
#  Text(80.61523341523342, 122.30999999999999, 'mse = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(83.90565110565112, 122.30999999999999, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(92.13169533169534, 167.60999999999999, 'X[0] <= 61.5\nmse = 0.062\nsamples = 60\nvalue = 0.067'),
#  Text(90.4864864864865, 158.55, 'X[4] <= 30.4\nmse = 0.096\nsamples = 37\nvalue = 0.108'),
#  Text(85.55085995085996, 149.49, 'X[4] <= 27.05\nmse = 0.188\nsamples = 12\nvalue = 0.25'),
#  Text(83.90565110565112, 140.43, 'mse = 0.0\nsamples = 6\nvalue = 0.0'),
#  Text(87.1960687960688, 140.43, 'X[3] <= 77.395\nmse = 0.25\nsamples = 6\nvalue = 0.5'),
#  Text(85.55085995085996, 131.37, 'mse = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(88.84127764127766, 131.37, 'X[3] <= 88.005\nmse = 0.188\nsamples = 4\nvalue = 0.25'),
#  Text(87.1960687960688, 122.30999999999999, 'mse = 0.0\nsamples = 3\nvalue = 0.0'),
#  Text(90.4864864864865, 122.30999999999999, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(95.42211302211302, 149.49, 'X[3] <= 68.105\nmse = 0.038\nsamples = 25\nvalue = 0.04'),
#  Text(93.77690417690418, 140.43, 'X[3] <= 66.935\nmse = 0.139\nsamples = 6\nvalue = 0.167'),
#  Text(92.13169533169534, 131.37, 'mse = 0.0\nsamples = 5\nvalue = 0.0'),
#  Text(95.42211302211302, 131.37, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(97.06732186732188, 140.43, 'mse = 0.0\nsamples = 19\nvalue = 0.0'),
#  Text(93.77690417690418, 158.55, 'mse = 0.0\nsamples = 23\nvalue = 0.0'),
#  Text(137.06646191646192, 185.73, 'X[3] <= 96.175\nmse = 0.07\nsamples = 503\nvalue = 0.076'),
#  Text(135.4212530712531, 176.67, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(138.71167076167077, 176.67, 'X[2] <= 0.5\nmse = 0.068\nsamples = 502\nvalue = 0.074'),
#  Text(119.4832923832924, 167.60999999999999, 'X[12] <= 0.5\nmse = 0.06\nsamples = 464\nvalue = 0.065'),
#  Text(103.64815724815726, 158.55, 'X[3] <= 213.23\nmse = 0.075\nsamples = 292\nvalue = 0.082'),
#  Text(102.00294840294842, 149.49, 'X[3] <= 211.785\nmse = 0.089\nsamples = 242\nvalue = 0.099'),
#  Text(100.35773955773956, 140.43, 'X[4] <= 23.7\nmse = 0.083\nsamples = 240\nvalue = 0.092'),
#  Text(98.71253071253072, 131.37, 'mse = 0.0\nsamples = 22\nvalue = 0.0'),
#  Text(102.00294840294842, 131.37, 'X[4] <= 24.0\nmse = 0.091\nsamples = 218\nvalue = 0.101'),
#  Text(100.35773955773956, 122.30999999999999, 'mse = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(103.64815724815726, 122.30999999999999, 'X[4] <= 26.35\nmse = 0.084\nsamples = 216\nvalue = 0.093'),
#  Text(102.00294840294842, 113.24999999999999, 'mse = 0.0\nsamples = 20\nvalue = 0.0'),
#  Text(105.2933660933661, 113.24999999999999, 'X[4] <= 27.35\nmse = 0.092\nsamples = 196\nvalue = 0.102'),
#  Text(94.59950859950861, 104.19, 'X[4] <= 27.25\nmse = 0.166\nsamples = 19\nvalue = 0.211'),
#  Text(92.95429975429977, 95.13, 'X[3] <= 98.295\nmse = 0.059\nsamples = 16\nvalue = 0.062'),
#  Text(91.30909090909091, 86.07, 'X[6] <= 0.5\nmse = 0.25\nsamples = 2\nvalue = 0.5'),
#  Text(89.66388206388207, 77.00999999999999, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(92.95429975429977, 77.00999999999999, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(94.59950859950861, 86.07, 'mse = 0.0\nsamples = 14\nvalue = 0.0'),
#  Text(96.24471744471745, 95.13, 'mse = 0.0\nsamples = 3\nvalue = 1.0'),
#  Text(115.9872235872236, 104.19, 'X[13] <= 0.5\nmse = 0.082\nsamples = 177\nvalue = 0.09'),
#  Text(106.11597051597053, 95.13, 'X[0] <= 50.5\nmse = 0.059\nsamples = 112\nvalue = 0.062'),
#  Text(99.53513513513515, 86.07, 'X[5] <= 0.5\nmse = 0.152\nsamples = 16\nvalue = 0.188'),
#  Text(96.24471744471745, 77.00999999999999, 'X[3] <= 112.455\nmse = 0.25\nsamples = 4\nvalue = 0.5'),
#  Text(94.59950859950861, 67.94999999999999, 'mse = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(97.8899262899263, 67.94999999999999, 'mse = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(102.82555282555283, 77.00999999999999, 'X[3] <= 157.665\nmse = 0.076\nsamples = 12\nvalue = 0.083'),
#  Text(101.18034398034399, 67.94999999999999, 'mse = 0.0\nsamples = 7\nvalue = 0.0'),
#  Text(104.47076167076168, 67.94999999999999, 'X[4] <= 39.1\nmse = 0.16\nsamples = 5\nvalue = 0.2'),
#  Text(102.82555282555283, 58.889999999999986, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(106.11597051597053, 58.889999999999986, 'mse = 0.0\nsamples = 4\nvalue = 0.0'),
#  Text(112.69680589680591, 86.07, 'X[3] <= 97.01\nmse = 0.04\nsamples = 96\nvalue = 0.042'),
#  Text(109.40638820638821, 77.00999999999999, 'X[3] <= 96.905\nmse = 0.16\nsamples = 5\nvalue = 0.2'),
#  Text(107.76117936117937, 67.94999999999999, 'mse = 0.0\nsamples = 4\nvalue = 0.0'),
#  Text(111.05159705159706, 67.94999999999999, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(115.9872235872236, 77.00999999999999, 'X[7] <= 0.5\nmse = 0.032\nsamples = 91\nvalue = 0.033'),
#  Text(114.34201474201475, 67.94999999999999, 'X[4] <= 28.55\nmse = 0.076\nsamples = 36\nvalue = 0.083'),
#  Text(111.05159705159706, 58.889999999999986, 'X[3] <= 105.36\nmse = 0.25\nsamples = 2\nvalue = 0.5'),
#  Text(109.40638820638821, 49.829999999999984, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(112.69680589680591, 49.829999999999984, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(117.63243243243244, 58.889999999999986, 'X[4] <= 35.4\nmse = 0.055\nsamples = 34\nvalue = 0.059'),
#  Text(115.9872235872236, 49.829999999999984, 'mse = 0.0\nsamples = 26\nvalue = 0.0'),
#  Text(119.2776412776413, 49.829999999999984, 'X[4] <= 35.8\nmse = 0.188\nsamples = 8\nvalue = 0.25'),
#  Text(117.63243243243244, 40.76999999999998, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(120.92285012285014, 40.76999999999998, 'X[0] <= 55.0\nmse = 0.122\nsamples = 7\nvalue = 0.143'),
#  Text(119.2776412776413, 31.70999999999998, 'X[4] <= 39.0\nmse = 0.25\nsamples = 2\nvalue = 0.5'),
#  Text(117.63243243243244, 22.649999999999977, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(120.92285012285014, 22.649999999999977, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(122.56805896805898, 31.70999999999998, 'mse = 0.0\nsamples = 5\nvalue = 0.0'),
#  Text(117.63243243243244, 67.94999999999999, 'mse = 0.0\nsamples = 55\nvalue = 0.0'),
#  Text(125.85847665847668, 95.13, 'X[0] <= 56.5\nmse = 0.119\nsamples = 65\nvalue = 0.138'),
#  Text(120.92285012285014, 86.07, 'X[1] <= 0.5\nmse = 0.03\nsamples = 32\nvalue = 0.031'),
#  Text(119.2776412776413, 77.00999999999999, 'mse = 0.0\nsamples = 27\nvalue = 0.0'),
#  Text(122.56805896805898, 77.00999999999999, 'X[6] <= 0.5\nmse = 0.16\nsamples = 5\nvalue = 0.2'),
#  Text(120.92285012285014, 67.94999999999999, 'mse = 0.0\nsamples = 4\nvalue = 0.0'),
#  Text(124.21326781326782, 67.94999999999999, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(130.7941031941032, 86.07, 'X[9] <= 0.5\nmse = 0.184\nsamples = 33\nvalue = 0.242'),
#  Text(129.14889434889437, 77.00999999999999, 'X[3] <= 205.18\nmse = 0.222\nsamples = 24\nvalue = 0.333'),
#  Text(127.50368550368552, 67.94999999999999, 'X[4] <= 28.25\nmse = 0.198\nsamples = 22\nvalue = 0.273'),
#  Text(125.85847665847668, 58.889999999999986, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(129.14889434889437, 58.889999999999986, 'X[4] <= 31.2\nmse = 0.181\nsamples = 21\nvalue = 0.238'),
#  Text(127.50368550368552, 49.829999999999984, 'mse = 0.0\nsamples = 8\nvalue = 0.0'),
#  Text(130.7941031941032, 49.829999999999984, 'X[4] <= 32.6\nmse = 0.237\nsamples = 13\nvalue = 0.385'),
#  Text(129.14889434889437, 40.76999999999998, 'mse = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(132.43931203931206, 40.76999999999998, 'X[0] <= 60.0\nmse = 0.198\nsamples = 11\nvalue = 0.273'),
#  Text(130.7941031941032, 31.70999999999998, 'X[3] <= 166.455\nmse = 0.245\nsamples = 7\nvalue = 0.429'),
#  Text(129.14889434889437, 22.649999999999977, 'X[3] <= 109.625\nmse = 0.16\nsamples = 5\nvalue = 0.2'),
#  Text(127.50368550368552, 13.589999999999975, 'X[3] <= 102.665\nmse = 0.25\nsamples = 2\nvalue = 0.5'),
#  Text(125.85847665847668, 4.529999999999973, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(129.14889434889437, 4.529999999999973, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(130.7941031941032, 13.589999999999975, 'mse = 0.0\nsamples = 3\nvalue = 0.0'),
#  Text(132.43931203931206, 22.649999999999977, 'mse = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(134.08452088452088, 31.70999999999998, 'mse = 0.0\nsamples = 4\nvalue = 0.0'),
#  Text(130.7941031941032, 67.94999999999999, 'mse = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(132.43931203931206, 77.00999999999999, 'mse = 0.0\nsamples = 9\nvalue = 0.0'),
#  Text(103.64815724815726, 140.43, 'mse = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(105.2933660933661, 149.49, 'mse = 0.0\nsamples = 50\nvalue = 0.0'),
#  Text(135.31842751842754, 158.55, 'X[3] <= 246.125\nmse = 0.034\nsamples = 172\nvalue = 0.035'),
#  Text(129.97149877149877, 149.49, 'X[3] <= 96.68\nmse = 0.029\nsamples = 170\nvalue = 0.029'),
#  Text(124.21326781326782, 140.43, 'X[3] <= 96.47\nmse = 0.222\nsamples = 3\nvalue = 0.333'),
#  Text(122.56805896805898, 131.37, 'mse = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(125.85847665847668, 131.37, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(135.72972972972974, 140.43, 'X[1] <= 0.5\nmse = 0.023\nsamples = 167\nvalue = 0.024'),
#  Text(129.14889434889437, 131.37, 'X[0] <= 62.5\nmse = 0.007\nsamples = 136\nvalue = 0.007'),
#  Text(127.50368550368552, 122.30999999999999, 'mse = 0.0\nsamples = 119\nvalue = 0.0'),
#  Text(130.7941031941032, 122.30999999999999, 'X[3] <= 207.215\nmse = 0.055\nsamples = 17\nvalue = 0.059'),
#  Text(129.14889434889437, 113.24999999999999, 'mse = 0.0\nsamples = 14\nvalue = 0.0'),
#  Text(132.43931203931206, 113.24999999999999, 'X[3] <= 210.785\nmse = 0.222\nsamples = 3\nvalue = 0.333'),
#  Text(130.7941031941032, 104.19, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(134.08452088452088, 104.19, 'mse = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(142.31056511056514, 131.37, 'X[0] <= 54.5\nmse = 0.087\nsamples = 31\nvalue = 0.097'),
#  Text(140.66535626535628, 122.30999999999999, 'X[6] <= 0.5\nmse = 0.188\nsamples = 12\nvalue = 0.25'),
#  Text(139.02014742014742, 113.24999999999999, 'X[7] <= 0.5\nmse = 0.245\nsamples = 7\nvalue = 0.429'),
#  Text(137.3749385749386, 104.19, 'X[3] <= 178.635\nmse = 0.24\nsamples = 5\nvalue = 0.6'),
#  Text(135.72972972972974, 95.13, 'X[9] <= 0.5\nmse = 0.222\nsamples = 3\nvalue = 0.333'),
#  Text(134.08452088452088, 86.07, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(137.3749385749386, 86.07, 'X[3] <= 171.875\nmse = 0.25\nsamples = 2\nvalue = 0.5'),
#  Text(135.72972972972974, 77.00999999999999, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(139.02014742014742, 77.00999999999999, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(139.02014742014742, 95.13, 'mse = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(140.66535626535628, 104.19, 'mse = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(142.31056511056514, 113.24999999999999, 'mse = 0.0\nsamples = 5\nvalue = 0.0'),
#  Text(143.95577395577396, 122.30999999999999, 'mse = 0.0\nsamples = 19\nvalue = 0.0'),
#  Text(140.66535626535628, 149.49, 'X[8] <= 0.5\nmse = 0.25\nsamples = 2\nvalue = 0.5'),
#  Text(139.02014742014742, 140.43, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(142.31056511056514, 140.43, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(157.94004914004915, 167.60999999999999, 'X[3] <= 239.9\nmse = 0.15\nsamples = 38\nvalue = 0.184'),
#  Text(156.2948402948403, 158.55, 'X[0] <= 54.5\nmse = 0.136\nsamples = 37\nvalue = 0.162'),
#  Text(154.64963144963147, 149.49, 'mse = 0.0\nsamples = 11\nvalue = 0.0'),
#  Text(157.94004914004915, 149.49, 'X[4] <= 36.05\nmse = 0.178\nsamples = 26\nvalue = 0.231'),
#  Text(152.1818181818182, 140.43, 'X[3] <= 120.32\nmse = 0.133\nsamples = 19\nvalue = 0.158'),
#  Text(148.8914004914005, 131.37, 'X[0] <= 63.5\nmse = 0.222\nsamples = 6\nvalue = 0.333'),
#  Text(147.24619164619165, 122.30999999999999, 'X[3] <= 110.75\nmse = 0.222\nsamples = 3\nvalue = 0.667'),
#  Text(145.60098280098282, 113.24999999999999, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(148.8914004914005, 113.24999999999999, 'mse = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(150.53660933660936, 122.30999999999999, 'mse = 0.0\nsamples = 3\nvalue = 0.0'),
#  Text(155.4722358722359, 131.37, 'X[0] <= 57.5\nmse = 0.071\nsamples = 13\nvalue = 0.077'),
#  Text(153.82702702702704, 122.30999999999999, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(157.11744471744473, 122.30999999999999, 'mse = 0.0\nsamples = 12\nvalue = 0.0'),
#  Text(163.69828009828012, 140.43, 'X[13] <= 0.5\nmse = 0.245\nsamples = 7\nvalue = 0.429'),
#  Text(162.05307125307127, 131.37, 'X[3] <= 195.495\nmse = 0.24\nsamples = 5\nvalue = 0.6'),
#  Text(160.4078624078624, 122.30999999999999, 'mse = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(163.69828009828012, 122.30999999999999, 'X[4] <= 39.5\nmse = 0.222\nsamples = 3\nvalue = 0.333'),
#  Text(162.05307125307127, 113.24999999999999, 'mse = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(165.34348894348895, 113.24999999999999, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(165.34348894348895, 131.37, 'mse = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(159.585257985258, 158.55, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(242.30841523341525, 203.85, 'X[3] <= 126.84\nmse = 0.132\nsamples = 666\nvalue = 0.156'),
#  Text(197.1165847665848, 194.79, 'X[4] <= 24.25\nmse = 0.103\nsamples = 453\nvalue = 0.117'),
#  Text(177.27125307125308, 185.73, 'X[0] <= 77.5\nmse = 0.173\nsamples = 90\nvalue = 0.222'),
#  Text(167.81130221130223, 176.67, 'X[11] <= 0.5\nmse = 0.057\nsamples = 33\nvalue = 0.061'),
#  Text(164.52088452088452, 167.60999999999999, 'X[1] <= 0.5\nmse = 0.25\nsamples = 2\nvalue = 0.5'),
#  Text(162.8756756756757, 158.55, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(166.16609336609338, 158.55, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(171.10171990171992, 167.60999999999999, 'X[1] <= 0.5\nmse = 0.031\nsamples = 31\nvalue = 0.032'),
#  Text(169.45651105651106, 158.55, 'mse = 0.0\nsamples = 28\nvalue = 0.0'),
#  Text(172.74692874692877, 158.55, 'X[12] <= 0.5\nmse = 0.222\nsamples = 3\nvalue = 0.333'),
#  Text(171.10171990171992, 149.49, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(174.3921375921376, 149.49, 'mse = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(186.73120393120394, 176.67, 'X[4] <= 23.3\nmse = 0.216\nsamples = 57\nvalue = 0.316'),
#  Text(180.972972972973, 167.60999999999999, 'X[6] <= 0.5\nmse = 0.171\nsamples = 41\nvalue = 0.22'),
#  Text(179.32776412776414, 158.55, 'X[3] <= 65.185\nmse = 0.198\nsamples = 33\nvalue = 0.273'),
#  Text(177.6825552825553, 149.49, 'mse = 0.0\nsamples = 6\nvalue = 0.0'),
#  Text(180.972972972973, 149.49, 'X[3] <= 98.205\nmse = 0.222\nsamples = 27\nvalue = 0.333'),
#  Text(179.32776412776414, 140.43, 'X[3] <= 97.355\nmse = 0.238\nsamples = 23\nvalue = 0.391'),
#  Text(177.6825552825553, 131.37, 'X[3] <= 67.56\nmse = 0.222\nsamples = 21\nvalue = 0.333'),
#  Text(176.03734643734646, 122.30999999999999, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(179.32776412776414, 122.30999999999999, 'X[12] <= 0.5\nmse = 0.21\nsamples = 20\nvalue = 0.3'),
#  Text(176.03734643734646, 113.24999999999999, 'X[3] <= 78.92\nmse = 0.139\nsamples = 12\nvalue = 0.167'),
#  Text(174.3921375921376, 104.19, 'X[3] <= 75.305\nmse = 0.24\nsamples = 5\nvalue = 0.4'),
#  Text(172.74692874692877, 95.13, 'mse = 0.0\nsamples = 3\nvalue = 0.0'),
#  Text(176.03734643734646, 95.13, 'mse = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(177.6825552825553, 104.19, 'mse = 0.0\nsamples = 7\nvalue = 0.0'),
#  Text(182.61818181818182, 113.24999999999999, 'X[2] <= 0.5\nmse = 0.25\nsamples = 8\nvalue = 0.5'),
#  Text(180.972972972973, 104.19, 'X[0] <= 81.5\nmse = 0.245\nsamples = 7\nvalue = 0.571'),
#  Text(179.32776412776414, 95.13, 'X[0] <= 79.5\nmse = 0.222\nsamples = 6\nvalue = 0.667'),
#  Text(177.6825552825553, 86.07, 'X[11] <= 0.5\nmse = 0.222\nsamples = 3\nvalue = 0.333'),
#  Text(176.03734643734646, 77.00999999999999, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(179.32776412776414, 77.00999999999999, 'mse = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(180.972972972973, 86.07, 'mse = 0.0\nsamples = 3\nvalue = 1.0'),
#  Text(182.61818181818182, 95.13, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(184.26339066339068, 104.19, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(180.972972972973, 131.37, 'mse = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(182.61818181818182, 140.43, 'mse = 0.0\nsamples = 4\nvalue = 0.0'),
#  Text(182.61818181818182, 158.55, 'mse = 0.0\nsamples = 8\nvalue = 0.0'),
#  Text(192.4894348894349, 167.60999999999999, 'X[5] <= 0.5\nmse = 0.246\nsamples = 16\nvalue = 0.562'),
#  Text(190.84422604422605, 158.55, 'mse = 0.0\nsamples = 4\nvalue = 1.0'),
#  Text(194.13464373464376, 158.55, 'X[9] <= 0.5\nmse = 0.243\nsamples = 12\nvalue = 0.417'),
#  Text(192.4894348894349, 149.49, 'X[4] <= 23.8\nmse = 0.234\nsamples = 8\nvalue = 0.625'),
#  Text(190.84422604422605, 140.43, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(194.13464373464376, 140.43, 'X[3] <= 94.815\nmse = 0.204\nsamples = 7\nvalue = 0.714'),
#  Text(192.4894348894349, 131.37, 'X[13] <= 0.5\nmse = 0.24\nsamples = 5\nvalue = 0.6'),
#  Text(190.84422604422605, 122.30999999999999, 'X[3] <= 68.45\nmse = 0.188\nsamples = 4\nvalue = 0.75'),
#  Text(189.19901719901722, 113.24999999999999, 'X[3] <= 63.47\nmse = 0.25\nsamples = 2\nvalue = 0.5'),
#  Text(187.55380835380836, 104.19, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(190.84422604422605, 104.19, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(192.4894348894349, 113.24999999999999, 'mse = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(194.13464373464376, 122.30999999999999, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(195.7798525798526, 131.37, 'mse = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(195.7798525798526, 149.49, 'mse = 0.0\nsamples = 4\nvalue = 0.0'),
#  Text(216.96191646191647, 185.73, 'X[1] <= 0.5\nmse = 0.083\nsamples = 363\nvalue = 0.091'),
#  Text(209.55847665847668, 176.67, 'X[4] <= 33.75\nmse = 0.068\nsamples = 287\nvalue = 0.073'),
#  Text(207.91326781326782, 167.60999999999999, 'X[3] <= 70.295\nmse = 0.08\nsamples = 239\nvalue = 0.088'),
#  Text(204.62285012285014, 158.55, 'X[4] <= 32.25\nmse = 0.019\nsamples = 52\nvalue = 0.019'),
#  Text(202.97764127764128, 149.49, 'mse = 0.0\nsamples = 46\nvalue = 0.0'),
#  Text(206.268058968059, 149.49, 'X[4] <= 32.35\nmse = 0.139\nsamples = 6\nvalue = 0.167'),
#  Text(204.62285012285014, 140.43, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(207.91326781326782, 140.43, 'mse = 0.0\nsamples = 5\nvalue = 0.0'),
#  Text(211.20368550368553, 158.55, 'X[3] <= 70.34\nmse = 0.096\nsamples = 187\nvalue = 0.107'),
#  Text(209.55847665847668, 149.49, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(212.84889434889436, 149.49, 'X[3] <= 109.6\nmse = 0.092\nsamples = 186\nvalue = 0.102'),
#  Text(211.20368550368553, 140.43, 'X[3] <= 109.35\nmse = 0.102\nsamples = 164\nvalue = 0.116'),
#  Text(209.55847665847668, 131.37, 'X[3] <= 104.795\nmse = 0.098\nsamples = 163\nvalue = 0.11'),
#  Text(204.41719901719904, 122.30999999999999, 'X[2] <= 0.5\nmse = 0.089\nsamples = 152\nvalue = 0.099'),
#  Text(202.77199017199018, 113.24999999999999, 'X[6] <= 0.5\nmse = 0.105\nsamples = 126\nvalue = 0.119'),
#  Text(194.13464373464376, 104.19, 'X[4] <= 24.65\nmse = 0.071\nsamples = 78\nvalue = 0.077'),
#  Text(190.84422604422605, 95.13, 'X[12] <= 0.5\nmse = 0.25\nsamples = 2\nvalue = 0.5'),
#  Text(189.19901719901722, 86.07, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(192.4894348894349, 86.07, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(197.42506142506144, 95.13, 'X[0] <= 77.5\nmse = 0.061\nsamples = 76\nvalue = 0.066'),
#  Text(195.7798525798526, 86.07, 'X[3] <= 90.005\nmse = 0.105\nsamples = 42\nvalue = 0.119'),
#  Text(190.02162162162165, 77.00999999999999, 'X[8] <= 0.5\nmse = 0.173\nsamples = 18\nvalue = 0.222'),
#  Text(186.73120393120394, 67.94999999999999, 'X[3] <= 89.31\nmse = 0.116\nsamples = 15\nvalue = 0.133'),
#  Text(185.0859950859951, 58.889999999999986, 'X[3] <= 77.13\nmse = 0.066\nsamples = 14\nvalue = 0.071'),
#  Text(183.44078624078625, 49.829999999999984, 'X[4] <= 27.5\nmse = 0.222\nsamples = 3\nvalue = 0.333'),
#  Text(181.79557739557742, 40.76999999999998, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(185.0859950859951, 40.76999999999998, 'mse = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(186.73120393120394, 49.829999999999984, 'mse = 0.0\nsamples = 11\nvalue = 0.0'),
#  Text(188.3764127764128, 58.889999999999986, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(193.31203931203933, 67.94999999999999, 'X[3] <= 76.54\nmse = 0.222\nsamples = 3\nvalue = 0.667'),
#  Text(191.66683046683048, 58.889999999999986, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(194.9572481572482, 58.889999999999986, 'mse = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(201.53808353808355, 77.00999999999999, 'X[4] <= 26.95\nmse = 0.04\nsamples = 24\nvalue = 0.042'),
#  Text(199.8928746928747, 67.94999999999999, 'X[4] <= 26.65\nmse = 0.109\nsamples = 8\nvalue = 0.125'),
#  Text(198.24766584766587, 58.889999999999986, 'mse = 0.0\nsamples = 7\nvalue = 0.0'),
#  Text(201.53808353808355, 58.889999999999986, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(203.1832923832924, 67.94999999999999, 'mse = 0.0\nsamples = 16\nvalue = 0.0'),
#  Text(199.0702702702703, 86.07, 'mse = 0.0\nsamples = 34\nvalue = 0.0'),
#  Text(211.40933660933663, 104.19, 'X[0] <= 78.5\nmse = 0.152\nsamples = 48\nvalue = 0.188'),
#  Text(208.11891891891895, 95.13, 'X[5] <= 0.5\nmse = 0.094\nsamples = 38\nvalue = 0.105'),
#  Text(206.4737100737101, 86.07, 'mse = 0.0\nsamples = 21\nvalue = 0.0'),
#  Text(209.76412776412778, 86.07, 'X[4] <= 27.6\nmse = 0.18\nsamples = 17\nvalue = 0.235'),
#  Text(208.11891891891895, 77.00999999999999, 'X[8] <= 0.5\nmse = 0.247\nsamples = 9\nvalue = 0.444'),
#  Text(206.4737100737101, 67.94999999999999, 'X[4] <= 27.1\nmse = 0.245\nsamples = 7\nvalue = 0.571'),
#  Text(204.82850122850124, 58.889999999999986, 'X[3] <= 86.625\nmse = 0.24\nsamples = 5\nvalue = 0.4'),
#  Text(203.1832923832924, 49.829999999999984, 'mse = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(206.4737100737101, 49.829999999999984, 'X[0] <= 73.0\nmse = 0.222\nsamples = 3\nvalue = 0.667'),
#  Text(204.82850122850124, 40.76999999999998, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(208.11891891891895, 40.76999999999998, 'mse = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(208.11891891891895, 58.889999999999986, 'mse = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(209.76412776412778, 67.94999999999999, 'mse = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(211.40933660933663, 77.00999999999999, 'mse = 0.0\nsamples = 8\nvalue = 0.0'),
#  Text(214.69975429975432, 95.13, 'X[4] <= 25.65\nmse = 0.25\nsamples = 10\nvalue = 0.5'),
#  Text(213.05454545454546, 86.07, 'mse = 0.0\nsamples = 3\nvalue = 0.0'),
#  Text(216.34496314496317, 86.07, 'X[9] <= 0.5\nmse = 0.204\nsamples = 7\nvalue = 0.714'),
#  Text(214.69975429975432, 77.00999999999999, 'mse = 0.0\nsamples = 3\nvalue = 1.0'),
#  Text(217.990171990172, 77.00999999999999, 'X[3] <= 88.415\nmse = 0.25\nsamples = 4\nvalue = 0.5'),
#  Text(216.34496314496317, 67.94999999999999, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(219.63538083538086, 67.94999999999999, 'X[12] <= 0.5\nmse = 0.222\nsamples = 3\nvalue = 0.667'),
#  Text(217.990171990172, 58.889999999999986, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(221.2805896805897, 58.889999999999986, 'mse = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(206.0624078624079, 113.24999999999999, 'mse = 0.0\nsamples = 26\nvalue = 0.0'),
#  Text(214.69975429975432, 122.30999999999999, 'X[4] <= 30.9\nmse = 0.198\nsamples = 11\nvalue = 0.273'),
#  Text(213.05454545454546, 113.24999999999999, 'mse = 0.0\nsamples = 6\nvalue = 0.0'),
#  Text(216.34496314496317, 113.24999999999999, 'X[0] <= 74.0\nmse = 0.24\nsamples = 5\nvalue = 0.6'),
#  Text(214.69975429975432, 104.19, 'mse = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(217.990171990172, 104.19, 'mse = 0.0\nsamples = 3\nvalue = 1.0'),
#  Text(212.84889434889436, 131.37, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(214.49410319410322, 140.43, 'mse = 0.0\nsamples = 22\nvalue = 0.0'),
#  Text(211.20368550368553, 167.60999999999999, 'mse = 0.0\nsamples = 48\nvalue = 0.0'),
#  Text(224.3653562653563, 176.67, 'X[11] <= 0.5\nmse = 0.133\nsamples = 76\nvalue = 0.158'),
#  Text(219.63538083538086, 167.60999999999999, 'X[6] <= 0.5\nmse = 0.24\nsamples = 5\nvalue = 0.6'),
#  Text(217.990171990172, 158.55, 'mse = 0.0\nsamples = 3\nvalue = 1.0'),
#  Text(221.2805896805897, 158.55, 'mse = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(229.0953316953317, 167.60999999999999, 'X[9] <= 0.5\nmse = 0.111\nsamples = 71\nvalue = 0.127'),
#  Text(224.5710073710074, 158.55, 'X[3] <= 84.18\nmse = 0.045\nsamples = 42\nvalue = 0.048'),
#  Text(222.92579852579854, 149.49, 'X[3] <= 80.29\nmse = 0.104\nsamples = 17\nvalue = 0.118'),
#  Text(221.2805896805897, 140.43, 'X[4] <= 27.75\nmse = 0.059\nsamples = 16\nvalue = 0.062'),
#  Text(219.63538083538086, 131.37, 'X[4] <= 27.15\nmse = 0.222\nsamples = 3\nvalue = 0.333'),
#  Text(217.990171990172, 122.30999999999999, 'mse = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(221.2805896805897, 122.30999999999999, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(222.92579852579854, 131.37, 'mse = 0.0\nsamples = 13\nvalue = 0.0'),
#  Text(224.5710073710074, 140.43, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(226.21621621621622, 149.49, 'mse = 0.0\nsamples = 25\nvalue = 0.0'),
#  Text(233.61965601965605, 158.55, 'X[4] <= 26.35\nmse = 0.183\nsamples = 29\nvalue = 0.241'),
#  Text(229.50663390663394, 149.49, 'X[3] <= 72.94\nmse = 0.24\nsamples = 5\nvalue = 0.6'),
#  Text(227.86142506142508, 140.43, 'mse = 0.0\nsamples = 3\nvalue = 1.0'),
#  Text(231.15184275184276, 140.43, 'mse = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(237.73267813267816, 149.49, 'X[4] <= 30.95\nmse = 0.139\nsamples = 24\nvalue = 0.167'),
#  Text(234.44226044226048, 140.43, 'X[3] <= 73.335\nmse = 0.059\nsamples = 16\nvalue = 0.062'),
#  Text(232.79705159705162, 131.37, 'X[3] <= 72.32\nmse = 0.222\nsamples = 3\nvalue = 0.333'),
#  Text(231.15184275184276, 122.30999999999999, 'mse = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(234.44226044226048, 122.30999999999999, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(236.0874692874693, 131.37, 'mse = 0.0\nsamples = 13\nvalue = 0.0'),
#  Text(241.02309582309584, 140.43, 'X[4] <= 34.25\nmse = 0.234\nsamples = 8\nvalue = 0.375'),
#  Text(239.377886977887, 131.37, 'X[3] <= 80.415\nmse = 0.188\nsamples = 4\nvalue = 0.75'),
#  Text(237.73267813267816, 122.30999999999999, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(241.02309582309584, 122.30999999999999, 'mse = 0.0\nsamples = 3\nvalue = 1.0'),
#  Text(242.6683046683047, 131.37, 'mse = 0.0\nsamples = 4\nvalue = 0.0'),
#  Text(287.5002457002457, 194.79, 'X[7] <= 0.5\nmse = 0.182\nsamples = 213\nvalue = 0.239'),
#  Text(266.1125307125307, 185.73, 'X[3] <= 200.83\nmse = 0.143\nsamples = 104\nvalue = 0.173'),
#  Text(256.6525798525799, 176.67, 'X[3] <= 193.91\nmse = 0.209\nsamples = 47\nvalue = 0.298'),
#  Text(250.89434889434892, 167.60999999999999, 'X[3] <= 136.27\nmse = 0.167\nsamples = 33\nvalue = 0.212'),
#  Text(247.60393120393124, 158.55, 'X[3] <= 132.825\nmse = 0.25\nsamples = 6\nvalue = 0.5'),
#  Text(245.95872235872238, 149.49, 'X[12] <= 0.5\nmse = 0.188\nsamples = 4\nvalue = 0.25'),
#  Text(244.31351351351353, 140.43, 'mse = 0.0\nsamples = 3\nvalue = 0.0'),
#  Text(247.60393120393124, 140.43, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(249.24914004914007, 149.49, 'mse = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(254.1847665847666, 158.55, 'X[5] <= 0.5\nmse = 0.126\nsamples = 27\nvalue = 0.148'),
#  Text(252.53955773955775, 149.49, 'X[0] <= 71.5\nmse = 0.204\nsamples = 14\nvalue = 0.286'),
#  Text(250.89434889434892, 140.43, 'mse = 0.0\nsamples = 5\nvalue = 0.0'),
#  Text(254.1847665847666, 140.43, 'X[4] <= 31.6\nmse = 0.247\nsamples = 9\nvalue = 0.444'),
#  Text(252.53955773955775, 131.37, 'mse = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(255.82997542997546, 131.37, 'X[0] <= 72.5\nmse = 0.204\nsamples = 7\nvalue = 0.286'),
#  Text(254.1847665847666, 122.30999999999999, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(257.4751842751843, 122.30999999999999, 'X[3] <= 164.865\nmse = 0.139\nsamples = 6\nvalue = 0.167'),
#  Text(255.82997542997546, 113.24999999999999, 'X[1] <= 0.5\nmse = 0.25\nsamples = 2\nvalue = 0.5'),
#  Text(254.1847665847666, 104.19, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(257.4751842751843, 104.19, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(259.12039312039315, 113.24999999999999, 'mse = 0.0\nsamples = 4\nvalue = 0.0'),
#  Text(255.82997542997546, 149.49, 'mse = 0.0\nsamples = 13\nvalue = 0.0'),
#  Text(262.41081081081086, 167.60999999999999, 'X[3] <= 195.33\nmse = 0.25\nsamples = 14\nvalue = 0.5'),
#  Text(260.765601965602, 158.55, 'mse = 0.0\nsamples = 4\nvalue = 1.0'),
#  Text(264.05601965601966, 158.55, 'X[0] <= 81.0\nmse = 0.21\nsamples = 10\nvalue = 0.3'),
#  Text(262.41081081081086, 149.49, 'X[4] <= 28.45\nmse = 0.109\nsamples = 8\nvalue = 0.125'),
#  Text(260.765601965602, 140.43, 'X[12] <= 0.5\nmse = 0.25\nsamples = 2\nvalue = 0.5'),
#  Text(259.12039312039315, 131.37, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(262.41081081081086, 131.37, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(264.05601965601966, 140.43, 'mse = 0.0\nsamples = 6\nvalue = 0.0'),
#  Text(265.7012285012285, 149.49, 'mse = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(275.5724815724816, 176.67, 'X[3] <= 219.765\nmse = 0.065\nsamples = 57\nvalue = 0.07'),
#  Text(273.92727272727274, 167.60999999999999, 'X[3] <= 216.505\nmse = 0.126\nsamples = 27\nvalue = 0.148'),
#  Text(270.6368550368551, 158.55, 'X[0] <= 68.5\nmse = 0.045\nsamples = 21\nvalue = 0.048'),
#  Text(268.9916461916462, 149.49, 'X[13] <= 0.5\nmse = 0.25\nsamples = 2\nvalue = 0.5'),
#  Text(267.34643734643737, 140.43, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(270.6368550368551, 140.43, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(272.2820638820639, 149.49, 'mse = 0.0\nsamples = 19\nvalue = 0.0'),
#  Text(277.21769041769045, 158.55, 'X[6] <= 0.5\nmse = 0.25\nsamples = 6\nvalue = 0.5'),
#  Text(275.5724815724816, 149.49, 'mse = 0.0\nsamples = 3\nvalue = 0.0'),
#  Text(278.8628992628993, 149.49, 'mse = 0.0\nsamples = 3\nvalue = 1.0'),
#  Text(277.21769041769045, 167.60999999999999, 'mse = 0.0\nsamples = 30\nvalue = 0.0'),
#  Text(308.88796068796074, 185.73, 'X[3] <= 221.265\nmse = 0.211\nsamples = 109\nvalue = 0.303'),
#  Text(296.13759213759215, 176.67, 'X[0] <= 78.5\nmse = 0.182\nsamples = 71\nvalue = 0.239'),
#  Text(287.0889434889435, 167.60999999999999, 'X[11] <= 0.5\nmse = 0.127\nsamples = 47\nvalue = 0.149'),
#  Text(283.7985257985258, 158.55, 'X[2] <= 0.5\nmse = 0.25\nsamples = 6\nvalue = 0.5'),
#  Text(282.15331695331696, 149.49, 'mse = 0.0\nsamples = 3\nvalue = 1.0'),
#  Text(285.4437346437347, 149.49, 'mse = 0.0\nsamples = 3\nvalue = 0.0'),
#  Text(290.3793611793612, 158.55, 'X[5] <= 0.5\nmse = 0.088\nsamples = 41\nvalue = 0.098'),
#  Text(288.7341523341524, 149.49, 'X[0] <= 68.5\nmse = 0.188\nsamples = 16\nvalue = 0.25'),
#  Text(285.4437346437347, 140.43, 'X[6] <= 0.5\nmse = 0.222\nsamples = 3\nvalue = 0.667'),
#  Text(283.7985257985258, 131.37, 'mse = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(287.0889434889435, 131.37, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(292.02457002457004, 140.43, 'X[0] <= 72.5\nmse = 0.13\nsamples = 13\nvalue = 0.154'),
#  Text(290.3793611793612, 131.37, 'mse = 0.0\nsamples = 8\nvalue = 0.0'),
#  Text(293.6697788697789, 131.37, 'X[4] <= 29.6\nmse = 0.24\nsamples = 5\nvalue = 0.4'),
#  Text(292.02457002457004, 122.30999999999999, 'mse = 0.0\nsamples = 3\nvalue = 0.0'),
#  Text(295.31498771498775, 122.30999999999999, 'mse = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(292.02457002457004, 149.49, 'mse = 0.0\nsamples = 25\nvalue = 0.0'),
#  Text(305.18624078624083, 167.60999999999999, 'X[4] <= 33.0\nmse = 0.243\nsamples = 24\nvalue = 0.417'),
#  Text(303.541031941032, 158.55, 'X[3] <= 214.41\nmse = 0.247\nsamples = 18\nvalue = 0.556'),
#  Text(301.8958230958231, 149.49, 'X[2] <= 0.5\nmse = 0.222\nsamples = 15\nvalue = 0.667'),
#  Text(298.6054054054054, 140.43, 'X[3] <= 176.54\nmse = 0.245\nsamples = 7\nvalue = 0.429'),
#  Text(296.9601965601966, 131.37, 'mse = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(300.25061425061426, 131.37, 'X[0] <= 80.5\nmse = 0.24\nsamples = 5\nvalue = 0.6'),
#  Text(298.6054054054054, 122.30999999999999, 'mse = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(301.8958230958231, 122.30999999999999, 'mse = 0.0\nsamples = 3\nvalue = 1.0'),
#  Text(305.18624078624083, 140.43, 'X[4] <= 31.05\nmse = 0.109\nsamples = 8\nvalue = 0.875'),
#  Text(303.541031941032, 131.37, 'mse = 0.0\nsamples = 5\nvalue = 1.0'),
#  Text(306.8314496314497, 131.37, 'X[12] <= 0.5\nmse = 0.222\nsamples = 3\nvalue = 0.667'),
#  Text(305.18624078624083, 122.30999999999999, 'mse = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(308.4766584766585, 122.30999999999999, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(305.18624078624083, 149.49, 'mse = 0.0\nsamples = 3\nvalue = 0.0'),
#  Text(306.8314496314497, 158.55, 'mse = 0.0\nsamples = 6\nvalue = 0.0'),
#  Text(321.6383292383293, 176.67, 'X[2] <= 0.5\nmse = 0.244\nsamples = 38\nvalue = 0.421'),
#  Text(313.41228501228505, 167.60999999999999, 'X[4] <= 31.65\nmse = 0.213\nsamples = 26\nvalue = 0.308'),
#  Text(310.12186732186734, 158.55, 'X[3] <= 224.6\nmse = 0.076\nsamples = 12\nvalue = 0.083'),
#  Text(308.4766584766585, 149.49, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(311.7670761670762, 149.49, 'mse = 0.0\nsamples = 11\nvalue = 0.0'),
#  Text(316.7027027027027, 158.55, 'X[4] <= 32.6\nmse = 0.25\nsamples = 14\nvalue = 0.5'),
#  Text(315.0574938574939, 149.49, 'mse = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(318.34791154791156, 149.49, 'X[0] <= 74.5\nmse = 0.243\nsamples = 12\nvalue = 0.417'),
#  Text(315.0574938574939, 140.43, 'X[0] <= 69.0\nmse = 0.222\nsamples = 6\nvalue = 0.667'),
#  Text(313.41228501228505, 131.37, 'X[13] <= 0.5\nmse = 0.222\nsamples = 3\nvalue = 0.333'),
#  Text(311.7670761670762, 122.30999999999999, 'X[3] <= 233.765\nmse = 0.25\nsamples = 2\nvalue = 0.5'),
#  Text(310.12186732186734, 113.24999999999999, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(313.41228501228505, 113.24999999999999, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(315.0574938574939, 122.30999999999999, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(316.7027027027027, 131.37, 'mse = 0.0\nsamples = 3\nvalue = 1.0'),
#  Text(321.6383292383293, 140.43, 'X[1] <= 0.5\nmse = 0.139\nsamples = 6\nvalue = 0.167'),
#  Text(319.9931203931204, 131.37, 'mse = 0.0\nsamples = 4\nvalue = 0.0'),
#  Text(323.28353808353813, 131.37, 'X[3] <= 235.43\nmse = 0.25\nsamples = 2\nvalue = 0.5'),
#  Text(321.6383292383293, 122.30999999999999, 'mse = 0.0\nsamples = 1\nvalue = 0.0'),
#  Text(324.92874692874693, 122.30999999999999, 'mse = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(329.8643734643735, 167.60999999999999, 'X[0] <= 68.5\nmse = 0.222\nsamples = 12\nvalue = 0.667'),
#  Text(328.21916461916464, 158.55, 'mse = 0.0\nsamples = 4\nvalue = 1.0'),
#  Text(331.50958230958236, 158.55, 'X[0] <= 78.5\nmse = 0.25\nsamples = 8\nvalue = 0.5'),
#  Text(329.8643734643735, 149.49, 'X[5] <= 0.5\nmse = 0.222\nsamples = 6\nvalue = 0.333'),
#  Text(328.21916461916464, 140.43, 'X[12] <= 0.5\nmse = 0.25\nsamples = 4\nvalue = 0.5'),
#  Text(326.5739557739558, 131.37, 'mse = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(329.8643734643735, 131.37, 'mse = 0.0\nsamples = 2\nvalue = 1.0'),
#  Text(331.50958230958236, 140.43, 'mse = 0.0\nsamples = 2\nvalue = 0.0'),
#  Text(333.1547911547912, 149.49, 'mse = 0.0\nsamples = 2\nvalue = 1.0')]

# %%
max_r_squared = 0
depth_max = 0
for d in range(1,30):
    regtree = tree.DecisionTreeRegressor(max_depth=d)
    regtree = regtree.fit(X_train, y_train)
    y_hat = regtree.predict(X_test)
    r_2 = r2_score(y_test, y_hat)
    print('R squared depth= ', d, ': ', r_2)
    if r_2 > max_r_squared:
        max_r_squared = r_2
        depth_max = d
    RMSE = math.sqrt(sum((y_test-y_hat)**2)/len(y_hat))
    print('RMSE: ', RMSE)
    
print('Best model is with depth=', depth_max, 'and a r squared of ', max_r_squared)
# Out:
# R squared depth=  1 :  0.05779368939505425
# RMSE:  0.1873059793940233
# R squared depth=  2 :  0.06351003568387326
# RMSE:  0.18673692420897806
# R squared depth=  3 :  0.044004519823724
# RMSE:  0.18867161058411733
# R squared depth=  4 :  0.0078120596790514085
# RMSE:  0.19220983651414614
# R squared depth=  5 :  -0.03007511770026805
# RMSE:  0.19584526933545046
# R squared depth=  6 :  -0.15047777059151524
# RMSE:  0.20697493417476923
# R squared depth=  7 :  -0.24834980694052278
# RMSE:  0.2155990220210811
# R squared depth=  8 :  -0.2223965219676145
# RMSE:  0.21334609104803756
# R squared depth=  9 :  -0.4436282092053274
# RMSE:  0.23184958197340857
# R squared depth=  10 :  -0.3297797230383881
# RMSE:  0.2225197126735074
# R squared depth=  11 :  -0.45463205611821333
# RMSE:  0.23273152447150633
# R squared depth=  12 :  -0.53426964637339
# RMSE:  0.23901738127751598
# R squared depth=  13 :  -0.45096855776522204
# RMSE:  0.2324382719418643
# R squared depth=  14 :  -0.39339202155353026
# RMSE:  0.22777984707023147
# R squared depth=  15 :  -0.7532439238615809
# RMSE:  0.2555052384030831
# R squared depth=  16 :  -0.6977115613128311
# RMSE:  0.25142623403832925
# R squared depth=  17 :  -0.7048256421834371
# RMSE:  0.2519524708602514
# R squared depth=  18 :  -0.7757677537085041
# RMSE:  0.2571412317796429
# R squared depth=  19 :  -0.6477639867339413
# RMSE:  0.24770007647750414
# R squared depth=  20 :  -0.7315468549422337
# RMSE:  0.2539193286935829
# R squared depth=  21 :  -0.8068315008092874
# RMSE:  0.2593805842035477
# R squared depth=  22 :  -0.6151978567840599
# RMSE:  0.24524010993077439
# R squared depth=  23 :  -0.7794552659485405
# RMSE:  0.25740807965160817
# R squared depth=  24 :  -0.8068315008092874
# RMSE:  0.2593805842035477
# R squared depth=  25 :  -0.8342077356700341
# RMSE:  0.26133820129024143
# R squared depth=  26 :  -0.7794552659485405
# RMSE:  0.25740807965160817
# R squared depth=  27 :  -0.8068315008092874
# RMSE:  0.2593805842035477
# R squared depth=  28 :  -0.8068315008092874
# RMSE:  0.2593805842035477
# R squared depth=  29 :  -0.9163364402522745
# RMSE:  0.2671249884027212
# Best model is with depth= 2 and a r squared of  0.06351003568387326

# %%
regtree = tree.DecisionTreeRegressor(max_depth=2)
regtree = regtree.fit(X_train, y_train)
y_hat = regtree.predict(X_test)
r_2 = r2_score(y_test, y_hat)
print('R squared depth= ', 2, ': ', r_2)
RMSE = math.sqrt(sum((y_test-y_hat)**2)/len(y_hat))
print('RMSE: ', RMSE)
plt.figure(figsize=(12,12))
tree.plot_tree(regtree, filled=True, feature_names=X_train.columns)
# Out:
# R squared depth=  2 :  0.06351003568387326
# RMSE:  0.18673692420897806
# [Text(334.8, 543.6, 'age <= 66.5\nmse = 0.042\nsamples = 3928\nvalue = 0.044'),
#  Text(167.4, 326.16, 'age <= 48.5\nmse = 0.02\nsamples = 3262\nvalue = 0.021'),
#  Text(83.7, 108.72000000000003, 'mse = 0.005\nsamples = 2194\nvalue = 0.005'),
#  Text(251.10000000000002, 108.72000000000003, 'mse = 0.049\nsamples = 1068\nvalue = 0.051'),
#  Text(502.20000000000005, 326.16, 'avg_glucose_level <= 126.84\nmse = 0.132\nsamples = 666\nvalue = 0.156'),
#  Text(418.5, 108.72000000000003, 'mse = 0.103\nsamples = 453\nvalue = 0.117'),
#  Text(585.9, 108.72000000000003, 'mse = 0.182\nsamples = 213\nvalue = 0.239')]

# %% [markdown]
# ## Classification Tree

# %%
from sklearn import tree
import math
from sklearn.metrics import r2_score

X_train = df_train_encoded.drop(['stroke', 'Unnamed: 0', 'id'], axis=1)
y_train = df_train_encoded['stroke']

X_test = df_test_encoded.drop(['stroke', 'Unnamed: 0', 'id'], axis=1)
y_test = df_test_encoded['stroke']

clastree = tree.DecisionTreeClassifier()
clastree.fit(X_train, y_train)

tree.plot_tree(clastree, filled=True)
# Out:
# [Text(152.888,219.764,'X[0] <= 66.5\ngini = 0.083\nsamples = 3928\nvalue = [3757, 171]'),
#  Text(60.0566,210.412,'X[0] <= 48.5\ngini = 0.04\nsamples = 3262\nvalue = [3195, 67]'),
#  Text(18.5142,201.061,'X[0] <= 37.5\ngini = 0.011\nsamples = 2194\nvalue = [2182, 12]'),
#  Text(6.51048,191.709,'X[3] <= 57.935\ngini = 0.003\nsamples = 1569\nvalue = [1567, 2]'),
#  Text(3.25524,182.358,'X[3] <= 57.925\ngini = 0.049\nsamples = 40\nvalue = [39, 1]'),
#  Text(1.62762,173.006,'gini = 0.0\nsamples = 39\nvalue = [39, 0]'),
#  Text(4.88286,173.006,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(9.76571,182.358,'X[0] <= 31.5\ngini = 0.001\nsamples = 1529\nvalue = [1528, 1]'),
#  Text(8.1381,173.006,'gini = 0.0\nsamples = 1236\nvalue = [1236, 0]'),
#  Text(11.3933,173.006,'X[0] <= 32.5\ngini = 0.007\nsamples = 293\nvalue = [292, 1]'),
#  Text(9.76571,163.654,'X[3] <= 76.645\ngini = 0.035\nsamples = 56\nvalue = [55, 1]'),
#  Text(8.1381,154.303,'X[3] <= 75.165\ngini = 0.117\nsamples = 16\nvalue = [15, 1]'),
#  Text(6.51048,144.951,'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(9.76571,144.951,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(11.3933,154.303,'gini = 0.0\nsamples = 40\nvalue = [40, 0]'),
#  Text(13.021,163.654,'gini = 0.0\nsamples = 237\nvalue = [237, 0]'),
#  Text(30.5179,191.709,'X[3] <= 97.77\ngini = 0.031\nsamples = 625\nvalue = [615, 10]'),
#  Text(26.8557,182.358,'X[3] <= 97.675\ngini = 0.049\nsamples = 361\nvalue = [352, 9]'),
#  Text(25.2281,173.006,'X[3] <= 82.26\ngini = 0.043\nsamples = 360\nvalue = [352, 8]'),
#  Text(19.5314,163.654,'X[1] <= 0.5\ngini = 0.019\nsamples = 208\nvalue = [206, 2]'),
#  Text(14.6486,154.303,'X[3] <= 78.145\ngini = 0.01\nsamples = 194\nvalue = [193, 1]'),
#  Text(13.021,144.951,'gini = 0.0\nsamples = 152\nvalue = [152, 0]'),
#  Text(16.2762,144.951,'X[3] <= 78.21\ngini = 0.046\nsamples = 42\nvalue = [41, 1]'),
#  Text(14.6486,135.599,'X[4] <= 31.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(13.021,126.248,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(16.2762,126.248,'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(17.9038,135.599,'gini = 0.0\nsamples = 40\nvalue = [40, 0]'),
#  Text(24.4143,154.303,'X[3] <= 59.54\ngini = 0.133\nsamples = 14\nvalue = [13, 1]'),
#  Text(22.7867,144.951,'X[4] <= 42.25\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(21.159,135.599,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(24.4143,135.599,'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(26.0419,144.951,'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(30.9248,163.654,'X[3] <= 82.3\ngini = 0.076\nsamples = 152\nvalue = [146, 6]'),
#  Text(29.2971,154.303,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(32.5524,154.303,'X[3] <= 84.255\ngini = 0.064\nsamples = 151\nvalue = [146, 5]'),
#  Text(29.2971,144.951,'X[3] <= 84.15\ngini = 0.211\nsamples = 25\nvalue = [22, 3]'),
#  Text(27.6695,135.599,'X[4] <= 26.7\ngini = 0.153\nsamples = 24\nvalue = [22, 2]'),
#  Text(26.0419,126.248,'X[4] <= 25.35\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(24.4143,116.896,'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(27.6695,116.896,'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(29.2971,126.248,'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(30.9248,135.599,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(35.8076,144.951,'X[13] <= 0.5\ngini = 0.031\nsamples = 126\nvalue = [124, 2]'),
#  Text(34.18,135.599,'gini = 0.0\nsamples = 101\nvalue = [101, 0]'),
#  Text(37.4352,135.599,'X[3] <= 93.29\ngini = 0.147\nsamples = 25\nvalue = [23, 2]'),
#  Text(34.18,126.248,'X[0] <= 46.5\ngini = 0.083\nsamples = 23\nvalue = [22, 1]'),
#  Text(32.5524,116.896,'gini = 0.0\nsamples = 21\nvalue = [21, 0]'),
#  Text(35.8076,116.896,'X[3] <= 88.995\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(34.18,107.544,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(37.4352,107.544,'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(40.6905,126.248,'X[0] <= 44.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(39.0629,116.896,'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(42.3181,116.896,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(28.4833,173.006,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(34.18,182.358,'X[4] <= 45.6\ngini = 0.008\nsamples = 264\nvalue = [263, 1]'),
#  Text(32.5524,173.006,'gini = 0.0\nsamples = 245\nvalue = [245, 0]'),
#  Text(35.8076,173.006,'X[4] <= 46.05\ngini = 0.1\nsamples = 19\nvalue = [18, 1]'),
#  Text(34.18,163.654,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(37.4352,163.654,'gini = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(101.599,201.061,'X[3] <= 96.11\ngini = 0.098\nsamples = 1068\nvalue = [1013, 55]'),
#  Text(65.5625,191.709,'X[11] <= 0.5\ngini = 0.058\nsamples = 565\nvalue = [548, 17]'),
#  Text(50.4562,182.358,'X[4] <= 37.3\ngini = 0.13\nsamples = 43\nvalue = [40, 3]'),
#  Text(47.201,173.006,'X[3] <= 92.22\ngini = 0.056\nsamples = 35\nvalue = [34, 1]'),
#  Text(45.5733,163.654,'gini = 0.0\nsamples = 30\nvalue = [30, 0]'),
#  Text(48.8286,163.654,'X[3] <= 92.715\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(47.201,154.303,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(50.4562,154.303,'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(53.7114,173.006,'X[4] <= 37.9\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(52.0838,163.654,'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(55.339,163.654,'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(80.6689,182.358,'X[1] <= 0.5\ngini = 0.052\nsamples = 522\nvalue = [508, 14]'),
#  Text(68.5635,173.006,'X[2] <= 0.5\ngini = 0.042\nsamples = 462\nvalue = [452, 10]'),
#  Text(60.6288,163.654,'X[6] <= 0.5\ngini = 0.036\nsamples = 436\nvalue = [428, 8]'),
#  Text(53.7114,154.303,'X[3] <= 64.285\ngini = 0.022\nsamples = 269\nvalue = [266, 3]'),
#  Text(50.4562,144.951,'X[3] <= 63.975\ngini = 0.087\nsamples = 44\nvalue = [42, 2]'),
#  Text(48.8286,135.599,'X[0] <= 49.5\ngini = 0.045\nsamples = 43\nvalue = [42, 1]'),
#  Text(47.201,126.248,'X[12] <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(45.5733,116.896,'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(48.8286,116.896,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(50.4562,126.248,'gini = 0.0\nsamples = 38\nvalue = [38, 0]'),
#  Text(52.0838,135.599,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(56.9667,144.951,'X[3] <= 92.965\ngini = 0.009\nsamples = 225\nvalue = [224, 1]'),
#  Text(55.339,135.599,'gini = 0.0\nsamples = 196\nvalue = [196, 0]'),
#  Text(58.5943,135.599,'X[3] <= 92.985\ngini = 0.067\nsamples = 29\nvalue = [28, 1]'),
#  Text(56.9667,126.248,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(60.2219,126.248,'gini = 0.0\nsamples = 28\nvalue = [28, 0]'),
#  Text(67.5462,154.303,'X[4] <= 21.3\ngini = 0.058\nsamples = 167\nvalue = [162, 5]'),
#  Text(63.4771,144.951,'X[3] <= 77.445\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(61.8495,135.599,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(65.1048,135.599,'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(71.6152,144.951,'X[3] <= 84.875\ngini = 0.048\nsamples = 164\nvalue = [160, 4]'),
#  Text(68.36,135.599,'X[12] <= 0.5\ngini = 0.019\nsamples = 104\nvalue = [103, 1]'),
#  Text(66.7324,126.248,'gini = 0.0\nsamples = 73\nvalue = [73, 0]'),
#  Text(69.9876,126.248,'X[4] <= 29.15\ngini = 0.062\nsamples = 31\nvalue = [30, 1]'),
#  Text(68.36,116.896,'X[4] <= 28.35\ngini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(66.7324,107.544,'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(69.9876,107.544,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(71.6152,116.896,'gini = 0.0\nsamples = 20\nvalue = [20, 0]'),
#  Text(74.8705,135.599,'X[3] <= 85.04\ngini = 0.095\nsamples = 60\nvalue = [57, 3]'),
#  Text(73.2429,126.248,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(76.4981,126.248,'X[3] <= 87.855\ngini = 0.065\nsamples = 59\nvalue = [57, 2]'),
#  Text(74.8705,116.896,'X[3] <= 87.68\ngini = 0.198\nsamples = 18\nvalue = [16, 2]'),
#  Text(73.2429,107.544,'X[0] <= 58.0\ngini = 0.111\nsamples = 17\nvalue = [16, 1]'),
#  Text(71.6152,98.1925,'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(74.8705,98.1925,'X[3] <= 86.14\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(73.2429,88.8408,'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(76.4981,88.8408,'X[13] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(74.8705,79.4892,'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(78.1257,79.4892,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(76.4981,107.544,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(78.1257,116.896,'gini = 0.0\nsamples = 41\nvalue = [41, 0]'),
#  Text(76.4981,163.654,'X[0] <= 58.5\ngini = 0.142\nsamples = 26\nvalue = [24, 2]'),
#  Text(74.8705,154.303,'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(78.1257,154.303,'X[0] <= 61.0\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(76.4981,144.951,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(79.7533,144.951,'X[8] <= 0.5\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(78.1257,135.599,'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(81.381,135.599,'X[5] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(79.7533,126.248,'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(83.0086,126.248,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(92.7743,173.006,'X[0] <= 61.5\ngini = 0.124\nsamples = 60\nvalue = [56, 4]'),
#  Text(91.1467,163.654,'X[4] <= 30.4\ngini = 0.193\nsamples = 37\nvalue = [33, 4]'),
#  Text(87.8914,154.303,'X[8] <= 0.5\ngini = 0.375\nsamples = 12\nvalue = [9, 3]'),
#  Text(86.2638,144.951,'X[3] <= 77.395\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(84.6362,135.599,'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(87.8914,135.599,'X[3] <= 88.005\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(86.2638,126.248,'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(89.519,126.248,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(89.519,144.951,'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(94.4019,154.303,'X[3] <= 68.105\ngini = 0.077\nsamples = 25\nvalue = [24, 1]'),
#  Text(92.7743,144.951,'X[3] <= 66.935\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(91.1467,135.599,'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(94.4019,135.599,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(96.0295,144.951,'gini = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(94.4019,163.654,'gini = 0.0\nsamples = 23\nvalue = [23, 0]'),
#  Text(137.636,191.709,'X[3] <= 96.175\ngini = 0.14\nsamples = 503\nvalue = [465, 38]'),
#  Text(136.008,182.358,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(139.263,182.358,'X[2] <= 0.5\ngini = 0.137\nsamples = 502\nvalue = [465, 37]'),
#  Text(119.833,173.006,'X[12] <= 0.5\ngini = 0.121\nsamples = 464\nvalue = [434, 30]'),
#  Text(102.54,163.654,'X[3] <= 213.23\ngini = 0.151\nsamples = 292\nvalue = [268, 24]'),
#  Text(100.912,154.303,'X[3] <= 211.785\ngini = 0.179\nsamples = 242\nvalue = [218, 24]'),
#  Text(99.2848,144.951,'X[4] <= 23.7\ngini = 0.167\nsamples = 240\nvalue = [218, 22]'),
#  Text(97.6571,135.599,'gini = 0.0\nsamples = 22\nvalue = [22, 0]'),
#  Text(100.912,135.599,'X[4] <= 24.0\ngini = 0.181\nsamples = 218\nvalue = [196, 22]'),
#  Text(99.2848,126.248,'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(102.54,126.248,'X[4] <= 26.35\ngini = 0.168\nsamples = 216\nvalue = [196, 20]'),
#  Text(100.912,116.896,'gini = 0.0\nsamples = 20\nvalue = [20, 0]'),
#  Text(104.168,116.896,'X[4] <= 27.35\ngini = 0.183\nsamples = 196\nvalue = [176, 20]'),
#  Text(93.5881,107.544,'X[4] <= 27.25\ngini = 0.332\nsamples = 19\nvalue = [15, 4]'),
#  Text(91.9605,98.1925,'X[3] <= 98.295\ngini = 0.117\nsamples = 16\nvalue = [15, 1]'),
#  Text(90.3329,88.8408,'X[0] <= 56.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(88.7052,79.4892,'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(91.9605,79.4892,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(93.5881,88.8408,'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(95.2157,98.1925,'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(114.747,107.544,'X[13] <= 0.5\ngini = 0.164\nsamples = 177\nvalue = [161, 16]'),
#  Text(104.981,98.1925,'X[0] <= 50.5\ngini = 0.117\nsamples = 112\nvalue = [105, 7]'),
#  Text(98.471,88.8408,'X[5] <= 0.5\ngini = 0.305\nsamples = 16\nvalue = [13, 3]'),
#  Text(95.2157,79.4892,'X[3] <= 112.455\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(93.5881,70.1375,'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(96.8433,70.1375,'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(101.726,79.4892,'X[3] <= 157.665\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(100.099,70.1375,'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(103.354,70.1375,'X[3] <= 173.485\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(101.726,60.7858,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(104.981,60.7858,'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(111.492,88.8408,'X[3] <= 97.01\ngini = 0.08\nsamples = 96\nvalue = [92, 4]'),
#  Text(108.237,79.4892,'X[4] <= 29.65\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(106.609,70.1375,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(109.864,70.1375,'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(114.747,79.4892,'X[7] <= 0.5\ngini = 0.064\nsamples = 91\nvalue = [88, 3]'),
#  Text(113.12,70.1375,'X[4] <= 28.55\ngini = 0.153\nsamples = 36\nvalue = [33, 3]'),
#  Text(109.864,60.7858,'X[0] <= 58.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(108.237,51.4342,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(111.492,51.4342,'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(116.375,60.7858,'X[4] <= 35.4\ngini = 0.111\nsamples = 34\nvalue = [32, 2]'),
#  Text(114.747,51.4342,'gini = 0.0\nsamples = 26\nvalue = [26, 0]'),
#  Text(118.002,51.4342,'X[4] <= 35.8\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(116.375,42.0825,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(119.63,42.0825,'X[3] <= 161.19\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(118.002,32.7308,'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(121.258,32.7308,'X[3] <= 196.635\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(119.63,23.3792,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(122.885,23.3792,'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(116.375,70.1375,'gini = 0.0\nsamples = 55\nvalue = [55, 0]'),
#  Text(124.513,98.1925,'X[0] <= 56.5\ngini = 0.239\nsamples = 65\nvalue = [56, 9]'),
#  Text(119.63,88.8408,'X[1] <= 0.5\ngini = 0.061\nsamples = 32\nvalue = [31, 1]'),
#  Text(118.002,79.4892,'gini = 0.0\nsamples = 27\nvalue = [27, 0]'),
#  Text(121.258,79.4892,'X[4] <= 41.45\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(119.63,70.1375,'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(122.885,70.1375,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(129.396,88.8408,'X[9] <= 0.5\ngini = 0.367\nsamples = 33\nvalue = [25, 8]'),
#  Text(127.768,79.4892,'X[3] <= 205.18\ngini = 0.444\nsamples = 24\nvalue = [16, 8]'),
#  Text(126.14,70.1375,'X[4] <= 28.25\ngini = 0.397\nsamples = 22\nvalue = [16, 6]'),
#  Text(124.513,60.7858,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(127.768,60.7858,'X[4] <= 31.2\ngini = 0.363\nsamples = 21\nvalue = [16, 5]'),
#  Text(126.14,51.4342,'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(129.396,51.4342,'X[4] <= 32.6\ngini = 0.473\nsamples = 13\nvalue = [8, 5]'),
#  Text(127.768,42.0825,'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(131.023,42.0825,'X[0] <= 60.0\ngini = 0.397\nsamples = 11\nvalue = [8, 3]'),
#  Text(129.396,32.7308,'X[3] <= 166.455\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(127.768,23.3792,'X[3] <= 109.625\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(126.14,14.0275,'X[0] <= 57.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(124.513,4.67583,'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(127.768,4.67583,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(129.396,14.0275,'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(131.023,23.3792,'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(132.651,32.7308,'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(129.396,70.1375,'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(131.023,79.4892,'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(102.54,144.951,'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(104.168,154.303,'gini = 0.0\nsamples = 50\nvalue = [50, 0]'),
#  Text(137.127,163.654,'X[3] <= 246.125\ngini = 0.067\nsamples = 172\nvalue = [166, 6]'),
#  Text(131.837,154.303,'X[3] <= 96.68\ngini = 0.057\nsamples = 170\nvalue = [165, 5]'),
#  Text(126.14,144.951,'X[3] <= 96.47\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(124.513,135.599,'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(127.768,135.599,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(137.534,144.951,'X[1] <= 0.5\ngini = 0.047\nsamples = 167\nvalue = [163, 4]'),
#  Text(131.023,135.599,'X[0] <= 62.5\ngini = 0.015\nsamples = 136\nvalue = [135, 1]'),
#  Text(129.396,126.248,'gini = 0.0\nsamples = 119\nvalue = [119, 0]'),
#  Text(132.651,126.248,'X[3] <= 207.215\ngini = 0.111\nsamples = 17\nvalue = [16, 1]'),
#  Text(131.023,116.896,'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(134.279,116.896,'X[3] <= 210.785\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(132.651,107.544,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(135.906,107.544,'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(144.044,135.599,'X[0] <= 54.5\ngini = 0.175\nsamples = 31\nvalue = [28, 3]'),
#  Text(142.417,126.248,'X[6] <= 0.5\ngini = 0.375\nsamples = 12\nvalue = [9, 3]'),
#  Text(140.789,116.896,'X[7] <= 0.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(139.161,107.544,'X[5] <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(137.534,98.1925,'X[8] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(135.906,88.8408,'X[4] <= 29.65\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(134.279,79.4892,'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(137.534,79.4892,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(139.161,88.8408,'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(140.789,98.1925,'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(142.417,107.544,'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(144.044,116.896,'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(145.672,126.248,'gini = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(142.417,154.303,'X[11] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(140.789,144.951,'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(144.044,144.951,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(158.693,173.006,'X[3] <= 239.9\ngini = 0.301\nsamples = 38\nvalue = [31, 7]'),
#  Text(157.065,163.654,'X[12] <= 0.5\ngini = 0.272\nsamples = 37\nvalue = [31, 6]'),
#  Text(155.438,154.303,'X[8] <= 0.5\ngini = 0.355\nsamples = 26\nvalue = [20, 6]'),
#  Text(153.81,144.951,'X[5] <= 0.5\ngini = 0.32\nsamples = 25\nvalue = [20, 5]'),
#  Text(150.555,135.599,'X[4] <= 28.85\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(148.927,126.248,'X[4] <= 26.9\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(147.3,116.896,'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(150.555,116.896,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(152.182,126.248,'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(157.065,135.599,'X[4] <= 30.85\ngini = 0.426\nsamples = 13\nvalue = [9, 4]'),
#  Text(155.438,126.248,'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(158.693,126.248,'X[4] <= 32.0\ngini = 0.463\nsamples = 11\nvalue = [7, 4]'),
#  Text(157.065,116.896,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(160.32,116.896,'X[4] <= 37.3\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(157.065,107.544,'X[7] <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(155.438,98.1925,'X[4] <= 33.75\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(153.81,88.8408,'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(157.065,88.8408,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(158.693,98.1925,'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(163.576,107.544,'X[3] <= 171.03\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(161.948,98.1925,'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(165.203,98.1925,'X[3] <= 195.495\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(163.576,88.8408,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(166.831,88.8408,'X[4] <= 39.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(165.203,79.4892,'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(168.459,79.4892,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(157.065,144.951,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(158.693,154.303,'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(160.32,163.654,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(245.72,210.412,'X[3] <= 126.84\ngini = 0.264\nsamples = 666\nvalue = [562, 104]'),
#  Text(199.282,201.061,'X[4] <= 24.25\ngini = 0.207\nsamples = 453\nvalue = [400, 53]'),
#  Text(176.597,191.709,'X[0] <= 77.5\ngini = 0.346\nsamples = 90\nvalue = [70, 20]'),
#  Text(168.459,182.358,'X[11] <= 0.5\ngini = 0.114\nsamples = 33\nvalue = [31, 2]'),
#  Text(165.203,173.006,'X[1] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(163.576,163.654,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(166.831,163.654,'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(171.714,173.006,'X[1] <= 0.5\ngini = 0.062\nsamples = 31\nvalue = [30, 1]'),
#  Text(170.086,163.654,'gini = 0.0\nsamples = 28\nvalue = [28, 0]'),
#  Text(173.341,163.654,'X[12] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(171.714,154.303,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(174.969,154.303,'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(184.735,182.358,'X[4] <= 23.3\ngini = 0.432\nsamples = 57\nvalue = [39, 18]'),
#  Text(181.48,173.006,'X[6] <= 0.5\ngini = 0.343\nsamples = 41\nvalue = [32, 9]'),
#  Text(179.852,163.654,'X[3] <= 65.185\ngini = 0.397\nsamples = 33\nvalue = [24, 9]'),
#  Text(178.224,154.303,'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(181.48,154.303,'X[3] <= 98.205\ngini = 0.444\nsamples = 27\nvalue = [18, 9]'),
#  Text(179.852,144.951,'X[3] <= 97.355\ngini = 0.476\nsamples = 23\nvalue = [14, 9]'),
#  Text(178.224,135.599,'X[3] <= 67.56\ngini = 0.444\nsamples = 21\nvalue = [14, 7]'),
#  Text(176.597,126.248,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(179.852,126.248,'X[12] <= 0.5\ngini = 0.42\nsamples = 20\nvalue = [14, 6]'),
#  Text(176.597,116.896,'X[3] <= 78.92\ngini = 0.278\nsamples = 12\nvalue = [10, 2]'),
#  Text(174.969,107.544,'X[3] <= 75.305\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(173.341,98.1925,'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(176.597,98.1925,'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(178.224,107.544,'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(183.107,116.896,'X[4] <= 18.2\ngini = 0.5\nsamples = 8\nvalue = [4, 4]'),
#  Text(181.48,107.544,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(184.735,107.544,'X[3] <= 75.77\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(183.107,98.1925,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(186.362,98.1925,'X[4] <= 22.85\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(184.735,88.8408,'X[0] <= 80.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(183.107,79.4892,'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(186.362,79.4892,'X[9] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(184.735,70.1375,'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(187.99,70.1375,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(187.99,88.8408,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(181.48,135.599,'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(183.107,144.951,'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(183.107,163.654,'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(187.99,173.006,'X[5] <= 0.5\ngini = 0.492\nsamples = 16\nvalue = [7, 9]'),
#  Text(186.362,163.654,'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(189.618,163.654,'X[7] <= 0.5\ngini = 0.486\nsamples = 12\nvalue = [7, 5]'),
#  Text(187.99,154.303,'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(191.245,154.303,'X[4] <= 23.8\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(189.618,144.951,'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(192.873,144.951,'X[0] <= 78.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(191.245,135.599,'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(194.5,135.599,'X[3] <= 68.45\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(192.873,126.248,'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(196.128,126.248,'X[4] <= 24.05\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(194.5,116.896,'X[6] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(192.873,107.544,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(196.128,107.544,'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(197.756,116.896,'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(221.967,191.709,'X[1] <= 0.5\ngini = 0.165\nsamples = 363\nvalue = [330, 33]'),
#  Text(214.642,182.358,'X[4] <= 33.75\ngini = 0.136\nsamples = 287\nvalue = [266, 21]'),
#  Text(213.015,173.006,'X[3] <= 70.295\ngini = 0.16\nsamples = 239\nvalue = [218, 21]'),
#  Text(209.759,163.654,'X[4] <= 32.25\ngini = 0.038\nsamples = 52\nvalue = [51, 1]'),
#  Text(208.132,154.303,'gini = 0.0\nsamples = 46\nvalue = [46, 0]'),
#  Text(211.387,154.303,'X[2] <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(209.759,144.951,'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(213.015,144.951,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(216.27,163.654,'X[3] <= 70.34\ngini = 0.191\nsamples = 187\nvalue = [167, 20]'),
#  Text(214.642,154.303,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(217.898,154.303,'X[3] <= 109.6\ngini = 0.183\nsamples = 186\nvalue = [167, 19]'),
#  Text(216.27,144.951,'X[3] <= 109.35\ngini = 0.205\nsamples = 164\nvalue = [145, 19]'),
#  Text(214.642,135.599,'X[3] <= 104.795\ngini = 0.196\nsamples = 163\nvalue = [145, 18]'),
#  Text(209.556,126.248,'X[2] <= 0.5\ngini = 0.178\nsamples = 152\nvalue = [137, 15]'),
#  Text(207.928,116.896,'X[6] <= 0.5\ngini = 0.21\nsamples = 126\nvalue = [111, 15]'),
#  Text(199.383,107.544,'X[4] <= 24.65\ngini = 0.142\nsamples = 78\nvalue = [72, 6]'),
#  Text(196.128,98.1925,'X[0] <= 73.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(194.5,88.8408,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(197.756,88.8408,'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(202.639,98.1925,'X[0] <= 77.5\ngini = 0.123\nsamples = 76\nvalue = [71, 5]'),
#  Text(201.011,88.8408,'X[3] <= 90.005\ngini = 0.21\nsamples = 42\nvalue = [37, 5]'),
#  Text(195.314,79.4892,'X[8] <= 0.5\ngini = 0.346\nsamples = 18\nvalue = [14, 4]'),
#  Text(192.059,70.1375,'X[3] <= 89.31\ngini = 0.231\nsamples = 15\nvalue = [13, 2]'),
#  Text(190.431,60.7858,'X[3] <= 77.13\ngini = 0.133\nsamples = 14\nvalue = [13, 1]'),
#  Text(188.804,51.4342,'X[3] <= 74.875\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(187.176,42.0825,'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(190.431,42.0825,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(192.059,51.4342,'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(193.687,60.7858,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(198.57,70.1375,'X[3] <= 76.54\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(196.942,60.7858,'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(200.197,60.7858,'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(206.708,79.4892,'X[4] <= 26.95\ngini = 0.08\nsamples = 24\nvalue = [23, 1]'),
#  Text(205.08,70.1375,'X[4] <= 26.65\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(203.452,60.7858,'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(206.708,60.7858,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(208.335,70.1375,'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(204.266,88.8408,'gini = 0.0\nsamples = 34\nvalue = [34, 0]'),
#  Text(216.473,107.544,'X[0] <= 78.5\ngini = 0.305\nsamples = 48\nvalue = [39, 9]'),
#  Text(213.218,98.1925,'X[5] <= 0.5\ngini = 0.188\nsamples = 38\nvalue = [34, 4]'),
#  Text(211.59,88.8408,'gini = 0.0\nsamples = 21\nvalue = [21, 0]'),
#  Text(214.846,88.8408,'X[4] <= 27.6\ngini = 0.36\nsamples = 17\nvalue = [13, 4]'),
#  Text(213.218,79.4892,'X[8] <= 0.5\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(211.59,70.1375,'X[4] <= 27.1\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(209.963,60.7858,'X[0] <= 73.0\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(208.335,51.4342,'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(211.59,51.4342,'X[4] <= 26.95\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(209.963,42.0825,'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(213.218,42.0825,'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(213.218,60.7858,'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(214.846,70.1375,'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(216.473,79.4892,'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(219.729,98.1925,'X[4] <= 25.65\ngini = 0.5\nsamples = 10\nvalue = [5, 5]'),
#  Text(218.101,88.8408,'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(221.356,88.8408,'X[7] <= 0.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(219.729,79.4892,'X[4] <= 29.2\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(218.101,70.1375,'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(221.356,70.1375,'X[12] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(219.729,60.7858,'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(222.984,60.7858,'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(222.984,79.4892,'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(211.184,116.896,'gini = 0.0\nsamples = 26\nvalue = [26, 0]'),
#  Text(219.729,126.248,'X[4] <= 30.9\ngini = 0.397\nsamples = 11\nvalue = [8, 3]'),
#  Text(218.101,116.896,'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(221.356,116.896,'X[0] <= 74.0\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(219.729,107.544,'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(222.984,107.544,'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(217.898,135.599,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(219.525,144.951,'gini = 0.0\nsamples = 22\nvalue = [22, 0]'),
#  Text(216.27,173.006,'gini = 0.0\nsamples = 48\nvalue = [48, 0]'),
#  Text(229.291,182.358,'X[11] <= 0.5\ngini = 0.266\nsamples = 76\nvalue = [64, 12]'),
#  Text(224.611,173.006,'X[6] <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(222.984,163.654,'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(226.239,163.654,'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(233.97,173.006,'X[9] <= 0.5\ngini = 0.221\nsamples = 71\nvalue = [62, 9]'),
#  Text(229.494,163.654,'X[3] <= 84.18\ngini = 0.091\nsamples = 42\nvalue = [40, 2]'),
#  Text(227.867,154.303,'X[3] <= 80.29\ngini = 0.208\nsamples = 17\nvalue = [15, 2]'),
#  Text(226.239,144.951,'X[4] <= 27.75\ngini = 0.117\nsamples = 16\nvalue = [15, 1]'),
#  Text(224.611,135.599,'X[4] <= 27.15\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(222.984,126.248,'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(226.239,126.248,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(227.867,135.599,'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(229.494,144.951,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(231.122,154.303,'gini = 0.0\nsamples = 25\nvalue = [25, 0]'),
#  Text(238.446,163.654,'X[4] <= 26.35\ngini = 0.366\nsamples = 29\nvalue = [22, 7]'),
#  Text(234.377,154.303,'X[3] <= 72.94\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(232.75,144.951,'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(236.005,144.951,'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(242.515,154.303,'X[4] <= 30.95\ngini = 0.278\nsamples = 24\nvalue = [20, 4]'),
#  Text(239.26,144.951,'X[3] <= 73.335\ngini = 0.117\nsamples = 16\nvalue = [15, 1]'),
#  Text(237.632,135.599,'X[3] <= 72.32\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(236.005,126.248,'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(239.26,126.248,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(240.888,135.599,'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(245.77,144.951,'X[4] <= 34.25\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(244.143,135.599,'X[3] <= 80.415\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(242.515,126.248,'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(245.77,126.248,'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(247.398,135.599,'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(292.158,201.061,'X[7] <= 0.5\ngini = 0.364\nsamples = 213\nvalue = [162, 51]'),
#  Text(270.592,191.709,'X[3] <= 200.83\ngini = 0.286\nsamples = 104\nvalue = [86, 18]'),
#  Text(261.233,182.358,'X[3] <= 193.91\ngini = 0.418\nsamples = 47\nvalue = [33, 14]'),
#  Text(255.536,173.006,'X[3] <= 136.27\ngini = 0.334\nsamples = 33\nvalue = [26, 7]'),
#  Text(252.281,163.654,'X[3] <= 132.825\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(250.653,154.303,'X[0] <= 73.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(249.026,144.951,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(252.281,144.951,'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(253.909,154.303,'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(258.791,163.654,'X[5] <= 0.5\ngini = 0.252\nsamples = 27\nvalue = [23, 4]'),
#  Text(257.164,154.303,'X[0] <= 71.5\ngini = 0.408\nsamples = 14\nvalue = [10, 4]'),
#  Text(255.536,144.951,'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(258.791,144.951,'X[4] <= 31.6\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(257.164,135.599,'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(260.419,135.599,'X[4] <= 35.7\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(258.791,126.248,'X[3] <= 164.865\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(257.164,116.896,'X[0] <= 77.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(255.536,107.544,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(258.791,107.544,'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(260.419,116.896,'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(262.047,126.248,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(260.419,154.303,'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(266.93,173.006,'X[3] <= 195.33\ngini = 0.5\nsamples = 14\nvalue = [7, 7]'),
#  Text(265.302,163.654,'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(268.557,163.654,'X[0] <= 81.0\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(266.93,154.303,'X[4] <= 28.45\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(265.302,144.951,'X[12] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(263.674,135.599,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(266.93,135.599,'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(268.557,144.951,'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(270.185,154.303,'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(279.95,182.358,'X[3] <= 219.765\ngini = 0.131\nsamples = 57\nvalue = [53, 4]'),
#  Text(278.323,173.006,'X[3] <= 216.505\ngini = 0.252\nsamples = 27\nvalue = [23, 4]'),
#  Text(275.068,163.654,'X[0] <= 68.5\ngini = 0.091\nsamples = 21\nvalue = [20, 1]'),
#  Text(273.44,154.303,'X[13] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(271.812,144.951,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(275.068,144.951,'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(276.695,154.303,'gini = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(281.578,163.654,'X[4] <= 32.15\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(279.95,154.303,'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(283.206,154.303,'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(281.578,173.006,'gini = 0.0\nsamples = 30\nvalue = [30, 0]'),
#  Text(313.724,191.709,'X[3] <= 221.265\ngini = 0.422\nsamples = 109\nvalue = [76, 33]'),
#  Text(300.296,182.358,'X[0] <= 78.5\ngini = 0.364\nsamples = 71\nvalue = [54, 17]'),
#  Text(291.344,173.006,'X[11] <= 0.5\ngini = 0.254\nsamples = 47\nvalue = [40, 7]'),
#  Text(288.089,163.654,'X[1] <= 0.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(286.461,154.303,'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(289.716,154.303,'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(294.599,163.654,'X[5] <= 0.5\ngini = 0.176\nsamples = 41\nvalue = [37, 4]'),
#  Text(292.971,154.303,'X[0] <= 68.5\ngini = 0.375\nsamples = 16\nvalue = [12, 4]'),
#  Text(289.716,144.951,'X[2] <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(288.089,135.599,'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(291.344,135.599,'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(296.227,144.951,'X[4] <= 33.5\ngini = 0.26\nsamples = 13\nvalue = [11, 2]'),
#  Text(294.599,135.599,'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(297.854,135.599,'X[0] <= 72.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(296.227,126.248,'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(299.482,126.248,'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(296.227,154.303,'gini = 0.0\nsamples = 25\nvalue = [25, 0]'),
#  Text(309.248,173.006,'X[4] <= 33.0\ngini = 0.486\nsamples = 24\nvalue = [14, 10]'),
#  Text(307.62,163.654,'X[3] <= 214.41\ngini = 0.494\nsamples = 18\nvalue = [8, 10]'),
#  Text(305.992,154.303,'X[2] <= 0.5\ngini = 0.444\nsamples = 15\nvalue = [5, 10]'),
#  Text(302.737,144.951,'X[0] <= 80.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(301.11,135.599,'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(304.365,135.599,'X[3] <= 176.54\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(302.737,126.248,'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(305.992,126.248,'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(309.248,144.951,'X[4] <= 31.05\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(307.62,135.599,'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(310.875,135.599,'X[4] <= 31.3\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(309.248,126.248,'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(312.503,126.248,'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(309.248,154.303,'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(310.875,163.654,'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(327.151,182.358,'X[2] <= 0.5\ngini = 0.488\nsamples = 38\nvalue = [22, 16]'),
#  Text(317.386,173.006,'X[4] <= 31.65\ngini = 0.426\nsamples = 26\nvalue = [18, 8]'),
#  Text(314.13,163.654,'X[3] <= 224.6\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(312.503,154.303,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(315.758,154.303,'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(320.641,163.654,'X[4] <= 32.6\ngini = 0.5\nsamples = 14\nvalue = [7, 7]'),
#  Text(319.013,154.303,'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(322.269,154.303,'X[0] <= 74.5\ngini = 0.486\nsamples = 12\nvalue = [7, 5]'),
#  Text(319.013,144.951,'X[0] <= 69.0\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(317.386,135.599,'X[4] <= 39.05\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(315.758,126.248,'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(319.013,126.248,'X[3] <= 233.765\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(317.386,116.896,'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(320.641,116.896,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(320.641,135.599,'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(325.524,144.951,'X[1] <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(323.896,135.599,'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(327.151,135.599,'X[4] <= 33.45\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(325.524,126.248,'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(328.779,126.248,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(336.917,173.006,'X[0] <= 68.5\ngini = 0.444\nsamples = 12\nvalue = [4, 8]'),
#  Text(335.29,163.654,'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(338.545,163.654,'X[0] <= 78.5\ngini = 0.5\nsamples = 8\nvalue = [4, 4]'),
#  Text(336.917,154.303,'X[6] <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(335.29,144.951,'X[5] <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(333.662,135.599,'X[4] <= 23.9\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(332.034,126.248,'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(335.29,126.248,'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(336.917,135.599,'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(338.545,144.951,'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(340.172,154.303,'gini = 0.0\nsamples = 2\nvalue = [0, 2]')]

# %%
y_hat = clastree.predict(X_test)

tab = pd.crosstab(y_test, y_hat)
acc = (tab.iloc[0,0]+tab.iloc[1,1])/(tab.iloc[0,0]+tab.iloc[0,1]+tab.iloc[1,0]+tab.iloc[1,1])
print(acc)
# Out:
# 0.9429153924566769

# %%
max_acc = 0
depth_max = 0
for d in range(1,30):
    clasree = tree.DecisionTreeClassifier(max_depth=d)
    clastree = clastree.fit(X_train, y_train)
    y_hat = clastree.predict(X_test)
    tab = pd.crosstab(y_test, y_hat)
    acc = (tab.iloc[0,0]+tab.iloc[1,1])/(tab.iloc[0,0]+tab.iloc[0,1]+tab.iloc[1,0]+tab.iloc[1,1])
    print('Accuracy depth= ', d, ': ', acc)
    if acc > max_acc:
        max_acc = acc
        depth_max = d
    
print('Best model is with depth=', depth_max, 'and a accuracy of ', max_acc)
# Out:
# Accuracy depth=  1 :  0.9347604485219164
# Accuracy depth=  2 :  0.9337410805300713
# Accuracy depth=  3 :  0.9337410805300713
# Accuracy depth=  4 :  0.9327217125382263
# Accuracy depth=  5 :  0.9418960244648318
# Accuracy depth=  6 :  0.9367991845056065
# Accuracy depth=  7 :  0.9337410805300713
# Accuracy depth=  8 :  0.9327217125382263
# Accuracy depth=  9 :  0.9347604485219164
# Accuracy depth=  10 :  0.9357798165137615
# Accuracy depth=  11 :  0.9378185524974516
# Accuracy depth=  12 :  0.9418960244648318
# Accuracy depth=  13 :  0.9306829765545361
# Accuracy depth=  14 :  0.9317023445463812
# Accuracy depth=  15 :  0.9347604485219164
# Accuracy depth=  16 :  0.9337410805300713
# Accuracy depth=  17 :  0.9357798165137615
# Accuracy depth=  18 :  0.9378185524974516
# Accuracy depth=  19 :  0.9367991845056065
# Accuracy depth=  20 :  0.9317023445463812
# Accuracy depth=  21 :  0.9327217125382263
# Accuracy depth=  22 :  0.9398572884811417
# Accuracy depth=  23 :  0.9327217125382263
# Accuracy depth=  24 :  0.9367991845056065
# Accuracy depth=  25 :  0.9337410805300713
# Accuracy depth=  26 :  0.9418960244648318
# Accuracy depth=  27 :  0.9388379204892966
# Accuracy depth=  28 :  0.9357798165137615
# Accuracy depth=  29 :  0.9327217125382263
# Best model is with depth= 5 and a accuracy of  0.9418960244648318

# %%
clastree = tree.DecisionTreeClassifier(max_depth=5)
clastree = clastree.fit(X_train, y_train)
plt.figure(figsize=(20,20))
tree.plot_tree(clastree, filled=True, feature_names=X_train.columns, fontsize=10)
# Out:
# [Text(554.481,1003.02,'age <= 66.5\ngini = 0.083\nsamples = 3928\nvalue = [3757, 171]'),
#  Text(285.429,820.65,'age <= 48.5\ngini = 0.04\nsamples = 3262\nvalue = [3195, 67]'),
#  Text(149.733,638.283,'age <= 37.5\ngini = 0.011\nsamples = 2194\nvalue = [2182, 12]'),
#  Text(74.8667,455.917,'avg_glucose_level <= 57.935\ngini = 0.003\nsamples = 1569\nvalue = [1567, 2]'),
#  Text(37.4333,273.55,'avg_glucose_level <= 57.925\ngini = 0.049\nsamples = 40\nvalue = [39, 1]'),
#  Text(18.7167,91.1833,'gini = 0.0\nsamples = 39\nvalue = [39, 0]'),
#  Text(56.15,91.1833,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(112.3,273.55,'age <= 31.5\ngini = 0.001\nsamples = 1529\nvalue = [1528, 1]'),
#  Text(93.5833,91.1833,'gini = 0.0\nsamples = 1236\nvalue = [1236, 0]'),
#  Text(131.017,91.1833,'gini = 0.007\nsamples = 293\nvalue = [292, 1]'),
#  Text(224.6,455.917,'avg_glucose_level <= 97.77\ngini = 0.031\nsamples = 625\nvalue = [615, 10]'),
#  Text(187.167,273.55,'avg_glucose_level <= 97.675\ngini = 0.049\nsamples = 361\nvalue = [352, 9]'),
#  Text(168.45,91.1833,'gini = 0.043\nsamples = 360\nvalue = [352, 8]'),
#  Text(205.883,91.1833,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(262.033,273.55,'bmi <= 45.6\ngini = 0.008\nsamples = 264\nvalue = [263, 1]'),
#  Text(243.317,91.1833,'gini = 0.0\nsamples = 245\nvalue = [245, 0]'),
#  Text(280.75,91.1833,'gini = 0.1\nsamples = 19\nvalue = [18, 1]'),
#  Text(421.125,638.283,'avg_glucose_level <= 96.11\ngini = 0.098\nsamples = 1068\nvalue = [1013, 55]'),
#  Text(374.333,455.917,'ever_married_Yes <= 0.5\ngini = 0.058\nsamples = 565\nvalue = [548, 17]'),
#  Text(336.9,273.55,'avg_glucose_level <= 88.935\ngini = 0.13\nsamples = 43\nvalue = [40, 3]'),
#  Text(318.183,91.1833,'gini = 0.056\nsamples = 35\nvalue = [34, 1]'),
#  Text(355.617,91.1833,'gini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(411.767,273.55,'hypertension <= 0.5\ngini = 0.052\nsamples = 522\nvalue = [508, 14]'),
#  Text(393.05,91.1833,'gini = 0.042\nsamples = 462\nvalue = [452, 10]'),
#  Text(430.483,91.1833,'gini = 0.124\nsamples = 60\nvalue = [56, 4]'),
#  Text(467.917,455.917,'avg_glucose_level <= 96.175\ngini = 0.14\nsamples = 503\nvalue = [465, 38]'),
#  Text(449.2,273.55,'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(486.633,273.55,'heart_disease <= 0.5\ngini = 0.137\nsamples = 502\nvalue = [465, 37]'),
#  Text(467.917,91.1833,'gini = 0.121\nsamples = 464\nvalue = [434, 30]'),
#  Text(505.35,91.1833,'gini = 0.301\nsamples = 38\nvalue = [31, 7]'),
#  Text(823.533,820.65,'avg_glucose_level <= 126.84\ngini = 0.264\nsamples = 666\nvalue = [562, 104]'),
#  Text(673.8,638.283,'bmi <= 24.25\ngini = 0.207\nsamples = 453\nvalue = [400, 53]'),
#  Text(598.933,455.917,'age <= 77.5\ngini = 0.346\nsamples = 90\nvalue = [70, 20]'),
#  Text(561.5,273.55,'ever_married_Yes <= 0.5\ngini = 0.114\nsamples = 33\nvalue = [31, 2]'),
#  Text(542.783,91.1833,'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(580.217,91.1833,'gini = 0.062\nsamples = 31\nvalue = [30, 1]'),
#  Text(636.367,273.55,'bmi <= 23.3\ngini = 0.432\nsamples = 57\nvalue = [39, 18]'),
#  Text(617.65,91.1833,'gini = 0.343\nsamples = 41\nvalue = [32, 9]'),
#  Text(655.083,91.1833,'gini = 0.492\nsamples = 16\nvalue = [7, 9]'),
#  Text(748.667,455.917,'hypertension <= 0.5\ngini = 0.165\nsamples = 363\nvalue = [330, 33]'),
#  Text(711.233,273.55,'bmi <= 33.75\ngini = 0.136\nsamples = 287\nvalue = [266, 21]'),
#  Text(692.517,91.1833,'gini = 0.16\nsamples = 239\nvalue = [218, 21]'),
#  Text(729.95,91.1833,'gini = 0.0\nsamples = 48\nvalue = [48, 0]'),
#  Text(786.1,273.55,'ever_married_Yes <= 0.5\ngini = 0.266\nsamples = 76\nvalue = [64, 12]'),
#  Text(767.383,91.1833,'gini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(804.817,91.1833,'gini = 0.221\nsamples = 71\nvalue = [62, 9]'),
#  Text(973.267,638.283,'work_type_Private Sector <= 0.5\ngini = 0.364\nsamples = 213\nvalue = [162, 51]'),
#  Text(898.4,455.917,'avg_glucose_level <= 200.83\ngini = 0.286\nsamples = 104\nvalue = [86, 18]'),
#  Text(860.967,273.55,'avg_glucose_level <= 193.91\ngini = 0.418\nsamples = 47\nvalue = [33, 14]'),
#  Text(842.25,91.1833,'gini = 0.334\nsamples = 33\nvalue = [26, 7]'),
#  Text(879.683,91.1833,'gini = 0.5\nsamples = 14\nvalue = [7, 7]'),
#  Text(935.833,273.55,'avg_glucose_level <= 219.765\ngini = 0.131\nsamples = 57\nvalue = [53, 4]'),
#  Text(917.117,91.1833,'gini = 0.252\nsamples = 27\nvalue = [23, 4]'),
#  Text(954.55,91.1833,'gini = 0.0\nsamples = 30\nvalue = [30, 0]'),
#  Text(1048.13,455.917,'avg_glucose_level <= 221.265\ngini = 0.422\nsamples = 109\nvalue = [76, 33]'),
#  Text(1010.7,273.55,'age <= 78.5\ngini = 0.364\nsamples = 71\nvalue = [54, 17]'),
#  Text(991.983,91.1833,'gini = 0.254\nsamples = 47\nvalue = [40, 7]'),
#  Text(1029.42,91.1833,'gini = 0.486\nsamples = 24\nvalue = [14, 10]'),
#  Text(1085.57,273.55,'heart_disease <= 0.5\ngini = 0.488\nsamples = 38\nvalue = [22, 16]'),
#  Text(1066.85,91.1833,'gini = 0.426\nsamples = 26\nvalue = [18, 8]'),
#  Text(1104.28,91.1833,'gini = 0.444\nsamples = 12\nvalue = [4, 8]')]

# %% [markdown]
# The classification tree does not provide information on predicting the chance of having a stroke, but helps determine the most influential features including age and average glucose level.
